# %%
#Importing Libraries
import pandas as pd
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
import os
from mpl_toolkits import mplot3d

from plotly.offline import download_plotlyjs, init_notebook_mode
from plotly.offline import plot, iplot
import plotly.graph_objects as go

# %% [markdown]
# ## Importing Dataframe

# %%
#Create a path to where your data is stored.
path= r'C:\Users\solom\Downloads\Machine Learning- Project'

# %%
#Read in the European weather data.
climate = pd.read_csv(os.path.join(path,'Manipulated Data', 'Weather_Data_Scaled.csv'))
climate
# Out:
#        Unnamed: 0     ID      DATE  MONTH  BASEL_cloud_cover  \
# 0               0      0  19600101      1           0.660514
# 1               1      1  19600102      1           0.244897
# 2               2      2  19600103      1           1.076130
# 3               3      3  19600104      1          -1.001953
# 4               4      4  19600105      1           0.244897
# ...           ...    ...       ...    ...                ...
# 22945       22945  22945  20221027     10          -1.833187
# 22946       22946  22946  20221028     10           0.244897
# 22947       22947  22947  20221029     10          -0.586336
# 22948       22948  22948  20221030     10          -0.170720
# 22949       22949  22949  20221031     10          -0.170720
#
#        BASEL_wind_speed  BASEL_humidity  BASEL_pressure  \
# 0              -0.02793        0.826097       -0.001949
# 1              -0.02793        0.735760       -0.001949
# 2              -0.02793        1.277781       -0.001949
# 3              -0.02793        1.458455       -0.001949
# 4              -0.02793        1.729466       -0.001949
# ...                 ...             ...             ...
# 22945          -0.02793        0.284075        1.037367
# 22946          -0.02793        0.103401        0.976231
# 22947          -0.02793        0.013064        0.716402
# 22948          -0.02793        0.374412        0.487141
# 22949          -0.02793        0.735760        0.196744
#
#        BASEL_global_radiation  BASEL_precipitation  ...  VALENTIA_cloud_cover  \
# 0                   -1.101066            -0.265148  ...             -0.443701
# 1                   -1.058108             1.658760  ...              0.783085
# 2                   -1.251420             0.155707  ...              0.783085
# 3                   -0.821838            -0.445514  ...              0.783085
# 4                   -0.746661            -0.164944  ...             -1.670486
# ...                       ...                  ...  ...                   ...
# 22945               -0.005632            -0.004619  ...             -0.443701
# 22946               -0.005632            -0.004619  ...             -0.443701
# 22947               -0.005632            -0.004619  ...             -0.443701
# 22948               -0.005632            -0.004619  ...             -0.443701
# 22949               -0.005632            -0.004619  ...             -0.443701
#
#        VALENTIA_humidity  VALENTIA_pressure  VALENTIA_global_radiation  \
# 0               0.761754          -1.299744                  -0.806427
# 1               1.183580          -1.262455                  -1.042055
# 2               1.183580          -0.432779                  -1.136306
# 3               0.480538           0.387574                  -1.183432
# 4              -0.363113           1.729970                  -0.794645
# ...                  ...                ...                        ...
# 22945          -0.081896          -0.003958                  -0.005290
# 22946          -0.081896          -0.003958                  -0.005290
# 22947          -0.081896          -0.003958                  -0.005290
# 22948          -0.081896          -0.003958                  -0.005290
# 22949          -0.081896          -0.003958                  -0.005290
#
#        VALENTIA_precipitation  VALENTIA_snow_depth  VALENTIA_sunshine  \
# 0                   -0.088407            -0.024706           0.372147
# 1                    0.503361            -0.024706          -0.829285
# 2                   -0.396127            -0.024706          -1.009500
# 3                    0.669056            -0.024706          -1.039536
# 4                   -0.490810            -0.024706           0.672505
# ...                       ...                  ...                ...
# 22945               -0.005560            -0.024706          -0.018319
# 22946               -0.005560            -0.024706          -0.018319
# 22947               -0.005560            -0.024706          -0.018319
# 22948               -0.005560            -0.024706          -0.018319
# 22949               -0.005560            -0.024706          -0.018319
#
#        VALENTIA_temp_mean  VALENTIA_temp_min  VALENTIA_temp_max
# 0               -0.668215          -0.519743          -0.752237
# 1               -0.548046          -0.629054          -0.407141
# 2               -0.067372           0.054135          -0.177078
# 3               -0.998679          -0.164486          -0.838511
# 4               -1.509396          -1.339569          -1.471186
# ...                   ...                ...                ...
# 22945           -0.007287          -0.000520          -0.004530
# 22946           -0.007287          -0.000520          -0.004530
# 22947           -0.007287          -0.000520          -0.004530
# 22948           -0.007287          -0.000520          -0.004530
# 22949           -0.007287          -0.000520          -0.004530
#
# [22950 rows x 172 columns]

# %%
climate_crop= climate.drop(columns=['Unnamed: 0', 'ID', 'DATE', 'MONTH'])
climate_crop
# Out:
#        BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  BASEL_pressure  \
# 0               0.660514          -0.02793        0.826097       -0.001949
# 1               0.244897          -0.02793        0.735760       -0.001949
# 2               1.076130          -0.02793        1.277781       -0.001949
# 3              -1.001953          -0.02793        1.458455       -0.001949
# 4               0.244897          -0.02793        1.729466       -0.001949
# ...                  ...               ...             ...             ...
# 22945          -1.833187          -0.02793        0.284075        1.037367
# 22946           0.244897          -0.02793        0.103401        0.976231
# 22947          -0.586336          -0.02793        0.013064        0.716402
# 22948          -0.170720          -0.02793        0.374412        0.487141
# 22949          -0.170720          -0.02793        0.735760        0.196744
#
#        BASEL_global_radiation  BASEL_precipitation  BASEL_snow_depth  \
# 0                   -1.101066            -0.265148         -0.179228
# 1                   -1.058108             1.658760         -0.179228
# 2                   -1.251420             0.155707         -0.179228
# 3                   -0.821838            -0.445514         -0.179228
# 4                   -0.746661            -0.164944         -0.179228
# ...                       ...                  ...               ...
# 22945               -0.005632            -0.004619         -0.179228
# 22946               -0.005632            -0.004619         -0.179228
# 22947               -0.005632            -0.004619         -0.179228
# 22948               -0.005632            -0.004619         -0.179228
# 22949               -0.005632            -0.004619         -0.179228
#
#        BASEL_sunshine  BASEL_temp_mean  BASEL_temp_min  ...  \
# 0           -0.902918        -0.528623       -0.845652  ...
# 1           -0.810126        -0.582946       -0.462450  ...
# 2           -1.065304        -0.257010       -0.186545  ...
# 3           -0.114186        -0.555784       -0.385810  ...
# 4            0.187388        -1.003946       -1.075573  ...
# ...               ...              ...             ...  ...
# 22945        0.720943         0.747959        0.779123  ...
# 22946        0.187388         0.856604        1.223637  ...
# 22947        0.349774         0.856604        1.039701  ...
# 22948        0.280180         0.680055        0.809780  ...
# 22949       -0.322968         0.422023        0.549202  ...
#
#        VALENTIA_cloud_cover  VALENTIA_humidity  VALENTIA_pressure  \
# 0                 -0.443701           0.761754          -1.299744
# 1                  0.783085           1.183580          -1.262455
# 2                  0.783085           1.183580          -0.432779
# 3                  0.783085           0.480538           0.387574
# 4                 -1.670486          -0.363113           1.729970
# ...                     ...                ...                ...
# 22945             -0.443701          -0.081896          -0.003958
# 22946             -0.443701          -0.081896          -0.003958
# 22947             -0.443701          -0.081896          -0.003958
# 22948             -0.443701          -0.081896          -0.003958
# 22949             -0.443701          -0.081896          -0.003958
#
#        VALENTIA_global_radiation  VALENTIA_precipitation  VALENTIA_snow_depth  \
# 0                      -0.806427               -0.088407            -0.024706
# 1                      -1.042055                0.503361            -0.024706
# 2                      -1.136306               -0.396127            -0.024706
# 3                      -1.183432                0.669056            -0.024706
# 4                      -0.794645               -0.490810            -0.024706
# ...                          ...                     ...                  ...
# 22945                  -0.005290               -0.005560            -0.024706
# 22946                  -0.005290               -0.005560            -0.024706
# 22947                  -0.005290               -0.005560            -0.024706
# 22948                  -0.005290               -0.005560            -0.024706
# 22949                  -0.005290               -0.005560            -0.024706
#
#        VALENTIA_sunshine  VALENTIA_temp_mean  VALENTIA_temp_min  \
# 0               0.372147           -0.668215          -0.519743
# 1              -0.829285           -0.548046          -0.629054
# 2              -1.009500           -0.067372           0.054135
# 3              -1.039536           -0.998679          -0.164486
# 4               0.672505           -1.509396          -1.339569
# ...                  ...                 ...                ...
# 22945          -0.018319           -0.007287          -0.000520
# 22946          -0.018319           -0.007287          -0.000520
# 22947          -0.018319           -0.007287          -0.000520
# 22948          -0.018319           -0.007287          -0.000520
# 22949          -0.018319           -0.007287          -0.000520
#
#        VALENTIA_temp_max
# 0              -0.752237
# 1              -0.407141
# 2              -0.177078
# 3              -0.838511
# 4              -1.471186
# ...                  ...
# 22945          -0.004530
# 22946          -0.004530
# 22947          -0.004530
# 22948          -0.004530
# 22949          -0.004530
#
# [22950 rows x 168 columns]

# %%
#Reduce to just the mean temperatures
df = climate[['DATE', 'MONTH','BASEL_temp_mean',
 'BELGRADE_temp_mean',
 'BUDAPEST_temp_mean',
 'DEBILT_temp_mean',
 'DUSSELDORF_temp_mean',
 'GDANSK_temp_mean',
 'HEATHROW_temp_mean',
 'KASSEL_temp_mean',
 'LJUBLJANA_temp_mean',
 'MAASTRICHT_temp_mean',
 'MADRID_temp_mean',
 'MUNCHENB_temp_mean',
 'OSLO_temp_mean',
 'ROMA_temp_mean',
 'SONNBLICK_temp_mean',
 'STOCKHOLM_temp_mean',
 'TOURS_temp_mean',
 'VALENTIA_temp_mean']].copy()

# %%
df
# Out:
#            DATE  MONTH  BASEL_temp_mean  BELGRADE_temp_mean  \
# 0      19600101      1        -0.528623           -1.016876
# 1      19600102      1        -0.582946           -1.107669
# 2      19600103      1        -0.257010           -1.084971
# 3      19600104      1        -0.555784           -1.209812
# 4      19600105      1        -1.003946           -1.209812
# ...         ...    ...              ...                 ...
# 22945  20221027     10         0.747959            0.628750
# 22946  20221028     10         0.856604            0.367720
# 22947  20221029     10         0.856604            0.083991
# 22948  20221030     10         0.680055            0.265577
# 22949  20221031     10         0.422023            0.197483
#
#        BUDAPEST_temp_mean  DEBILT_temp_mean  DUSSELDORF_temp_mean  \
# 0               -1.099163         -0.114356             -0.105836
# 1               -1.110927         -0.367511             -0.370915
# 2               -1.063873         -0.509912             -0.532908
# 3               -1.146217         -0.525734             -0.577088
# 4               -1.087400         -0.320045             -0.444548
# ...                   ...               ...                   ...
# 22945           -0.005167          0.898267              1.042841
# 22946           -0.005167          0.945734              1.278467
# 22947           -0.005167          0.914089              1.101748
# 22948           -0.005167          0.692578              0.880848
# 22949           -0.005167          0.439422              0.659949
#
#        GDANSK_temp_mean  HEATHROW_temp_mean  KASSEL_temp_mean  \
# 0             -0.927601           -0.106469         -0.182904
# 1             -0.825294           -0.892676         -0.212437
# 2             -0.940389           -0.490837         -0.389635
# 3             -1.042696           -0.316124         -0.493001
# 4             -0.978754           -0.403481         -0.552067
# ...                 ...                 ...               ...
# 22945          0.440753            0.906865         -0.005705
# 22946          0.466330            0.802037         -0.005705
# 22947          0.786039            0.924336         -0.005705
# 22948          0.376811            0.697210         -0.005705
# 22949          0.159409            0.435140         -0.005705
#
#        LJUBLJANA_temp_mean  MAASTRICHT_temp_mean  MADRID_temp_mean  \
# 0                -1.370824             -0.097084         -0.988280
# 1                -1.043881             -0.232112         -0.691740
# 2                -0.741156             -0.487164         -0.853490
# 3                -0.910682             -0.472161         -0.624345
# 4                -0.862246             -0.307127         -0.381721
# ...                    ...                   ...               ...
# 22945             0.481853              1.268193          0.683127
# 22946             0.263891              1.313202          0.561815
# 22947             0.300218              1.208181          0.548336
# 22948             0.397090              0.923123          0.103526
# 22949             0.348654              0.773092         -0.112140
#
#        MUNCHENB_temp_mean  OSLO_temp_mean  ROMA_temp_mean  \
# 0               -0.265742       -0.186575       -1.280450
# 1               -0.353714       -0.368598       -0.539569
# 2               -0.403983       -0.550620       -0.876333
# 3               -0.642763       -0.417137       -0.775304
# 4               -0.906678       -0.332193       -0.926848
# ...                   ...             ...             ...
# 22945            0.664244        0.395898       -0.000746
# 22946            0.890456        0.541516       -0.000746
# 22947            1.053832        0.395898       -0.000746
# 22948            0.689378       -0.065226       -0.000746
# 22949            0.488300        0.335224       -0.000746
#
#        SONNBLICK_temp_mean  STOCKHOLM_temp_mean  TOURS_temp_mean  \
# 0                -0.124331            -0.391072        -0.257321
# 1                -0.650834            -0.415953        -0.335759
# 2                -0.650834            -0.615003        -0.210258
# 3                -0.943336            -0.764290        -0.069069
# 4                -0.621584            -0.503037        -0.037694
# ...                    ...                  ...              ...
# 22945             0.826301             0.517090         1.295755
# 22946             1.074927             0.641496         1.358505
# 22947             1.221178             0.716139         1.405568
# 22948             1.235803             0.019467         0.668249
# 22949             0.987177             0.293160         0.809438
#
#        VALENTIA_temp_mean
# 0               -0.668215
# 1               -0.548046
# 2               -0.067372
# 3               -0.998679
# 4               -1.509396
# ...                   ...
# 22945           -0.007287
# 22946           -0.007287
# 22947           -0.007287
# 22948           -0.007287
# 22949           -0.007287
#
# [22950 rows x 20 columns]

# %%
#You'll need to reduce the dataset to only one year of data. Analyze and pick which year you want to use.

# %%
#Drop the DATE and MONTH data as those numbers are not scaled with the rest.
notemp = df.drop(['DATE','MONTH'], axis=1)

# %%
#Look at a whisker plot of the data to see variations in temperatures
notemp.boxplot(figsize=(15,15))
plt.xticks(rotation=90)
plt.show()

# %%
#Reduce your dataset to a single year
df1970 = df[df['DATE'].astype(str).str.contains('1970')] #<-----INSERT YEAR HERE
df1970
# Out:
#           DATE  MONTH  BASEL_temp_mean  BELGRADE_temp_mean  \
# 3653  19700101      1        -1.900269           -1.380049
# 3654  19700102      1        -1.968172           -1.629730
# 3655  19700103      1        -1.710140           -1.300605
# 3656  19700104      1        -1.520011           -0.926083
# 3657  19700105      1        -1.112591           -0.449419
# ...        ...    ...              ...                 ...
# 4013  19701227     12        -2.348431           -1.221161
# 4014  19701228     12        -2.063237           -0.744497
# 4015  19701229     12        -1.968172           -0.267832
# 4016  19701230     12        -1.669398           -0.256483
# 4017  19701231     12        -2.199044           -0.528863
#
#       BUDAPEST_temp_mean  DEBILT_temp_mean  DUSSELDORF_temp_mean  \
# 3653           -1.416775         -3.088935             -2.889169
# 3654           -1.581463         -1.490890             -1.666859
# 3655           -1.934365         -1.617468             -1.475413
# 3656           -1.734387         -2.171246             -2.079204
# 3657           -1.052110         -1.981379             -1.902485
# ...                  ...               ...                   ...
# 4013           -2.204923         -2.598446             -2.491550
# 4014           -1.216797         -2.044668             -1.902485
# 4015           -1.287378         -2.013024             -1.902485
# 4016           -0.934476         -1.981379             -2.108658
# 4017           -1.216797         -2.361113             -2.491550
#
#       GDANSK_temp_mean  HEATHROW_temp_mean  KASSEL_temp_mean  \
# 3653         -3.357388           -1.923481         -2.678447
# 3654         -1.809997           -1.626469         -1.895821
# 3655         -1.451923           -1.643941         -1.526658
# 3656         -1.541442           -2.272906         -1.940121
# 3657         -1.464712           -2.430148         -1.733389
# ...                ...                 ...               ...
# 4013         -1.490288           -2.133136         -2.205918
# 4014         -1.298463           -1.906010         -1.689090
# 4015         -1.196156           -1.678883         -1.733389
# 4016         -1.068273           -1.661412         -1.792455
# 4017         -1.937881           -1.958424         -2.560315
#
#       LJUBLJANA_temp_mean  MAASTRICHT_temp_mean  MADRID_temp_mean  \
# 3653            -1.455587             -2.842642         -1.392653
# 3654            -1.673549             -1.792429         -1.810505
# 3655            -1.431369             -1.387347         -1.500486
# 3656            -1.043881             -1.987469         -0.637824
# 3657            -1.019663             -1.852441         -0.732178
# ...                   ...                   ...               ...
# 4013            -1.782530             -2.422557         -2.107045
# 4014            -1.649331             -2.152502         -1.864421
# 4015            -1.358715             -2.047481         -2.012691
# 4016            -0.971227             -2.137499         -2.053129
# 4017            -1.286061             -2.602594         -1.864421
#
#       MUNCHENB_temp_mean  OSLO_temp_mean  ROMA_temp_mean  SONNBLICK_temp_mean  \
# 3653           -1.798962       -1.254442       -1.179421            -1.528340
# 3654           -1.685856       -1.654892       -1.566700            -1.791591
# 3655           -1.283700       -1.909724       -1.246774            -1.221213
# 3656           -1.459643       -2.358713       -1.027877            -1.060337
# 3657           -1.283700       -2.492197       -0.253319            -0.621584
# ...                  ...             ...             ...                  ...
# 4013           -2.377061       -1.072419       -0.758466            -1.367464
# 4014           -1.899501       -0.999610       -0.674275            -1.074962
# 4015           -1.635586       -1.400060       -0.371187            -1.118837
# 4016           -1.597884       -1.485004       -0.674275            -0.855585
# 4017           -1.886934       -1.836915       -0.859495            -1.733091
#
#       STOCKHOLM_temp_mean  TOURS_temp_mean  VALENTIA_temp_mean
# 3653            -1.660011        -2.139837           -2.260450
# 3654            -1.535605        -1.857459           -1.809817
# 3655            -1.971026        -1.747646           -1.599522
# 3656            -2.070550        -2.030023           -2.650998
# 3657            -2.854307        -1.998648           -2.560871
# ...                   ...              ...                 ...
# 4013            -1.324116        -2.579090           -3.011504
# 4014            -1.174829        -2.406526           -2.500787
# 4015            -1.261913        -2.375151           -2.620956
# 4016            -1.759536        -2.233962           -2.200365
# 4017            -2.120313        -2.798717           -2.951420
#
# [365 rows x 20 columns]

# %%
df1970.describe()
# Out:
#                DATE       MONTH  BASEL_temp_mean  BELGRADE_temp_mean  \
# count  3.650000e+02  365.000000       365.000000          365.000000
# mean   1.970067e+07    6.526027        -0.133779           -0.109784
# std    3.454755e+02    3.452584         1.017559            0.924237
# min    1.970010e+07    1.000000        -2.348431           -2.026950
# 25%    1.970040e+07    4.000000        -1.003946           -0.835290
# 50%    1.970070e+07    7.000000        -0.161945           -0.052199
# 75%    1.970100e+07   10.000000         0.652894            0.628750
# max    1.970123e+07   12.000000         1.847992            1.650173
#
#        BUDAPEST_temp_mean  DEBILT_temp_mean  DUSSELDORF_temp_mean  \
# count          365.000000        365.000000            365.000000
# mean            -0.113229         -0.139411             -0.135330
# std              0.996474          1.079347              1.053106
# min             -2.204923         -3.088935             -2.889169
# 25%             -0.969766         -0.968756             -0.930527
# 50%             -0.099274          0.028044             -0.135289
# 75%              0.724164          0.724222              0.718855
# max              1.641710          2.100757              1.838079
#
#        GDANSK_temp_mean  HEATHROW_temp_mean  KASSEL_temp_mean  \
# count        365.000000          365.000000        365.000000
# mean          -0.172282           -0.086796         -0.045555
# std            1.079882            1.065428          1.125148
# min           -3.459695           -2.430148         -2.678447
# 25%           -0.978754           -0.910147         -0.950763
# 50%           -0.096358           -0.019113          0.009061
# 75%            0.773250            0.802037          0.880287
# max            1.975355            2.234681          2.091142
#
#        LJUBLJANA_temp_mean  MAASTRICHT_temp_mean  MADRID_temp_mean  \
# count           365.000000            365.000000        365.000000
# mean             -0.121042             -0.137325         -0.085698
# std               0.991954              1.025780          1.010199
# min              -2.170018             -2.842642         -2.187919
# 25%              -0.983336             -0.907249         -0.947843
# 50%              -0.147815             -0.112087         -0.233451
# 75%               0.699815              0.668071          0.885313
# max               1.813844              1.823306          1.788412
#
#        MUNCHENB_temp_mean  OSLO_temp_mean  ROMA_temp_mean  \
# count          365.000000      365.000000      365.000000
# mean            -0.185690       -0.177366       -0.012787
# std              1.013268        1.163289        1.088088
# min             -3.017997       -2.977591       -2.358096
# 25%             -1.019785       -1.036014       -0.926848
# 50%             -0.165203       -0.198710       -0.185966
# 75%              0.664244        0.869157        1.060061
# max              1.833009        2.167587        2.104030
#
#        SONNBLICK_temp_mean  STOCKHOLM_temp_mean  TOURS_temp_mean  \
# count           365.000000           365.000000       365.000000
# mean             -0.196054            -0.222937        -0.113811
# std               1.053555             1.159896         1.025732
# min              -3.122475            -3.115559        -2.892843
# 25%              -0.987211            -1.050423        -0.853451
# 50%              -0.138956            -0.291548        -0.131820
# 75%               0.665425             0.865426         0.699625
# max               1.908558             1.985078         1.986010
#
#        VALENTIA_temp_mean
# count          365.000000
# mean            -0.085068
# std              1.212600
# min             -3.011504
# 25%             -0.998679
# 50%              0.052797
# 75%              0.954062
# max              2.426128

# %%
#Reduce your dataset to a single year
df1997 = df[df['DATE'].astype(str).str.contains('1997')] #<-----INSERT YEAR HERE
df1997
# Out:
#            DATE  MONTH  BASEL_temp_mean  BELGRADE_temp_mean  \
# 13515  19970101      1        -2.850915           -1.902110
# 13516  19970102      1        -2.837334           -1.731872
# 13517  19970103      1        -2.253366           -1.346001
# 13518  19970104      1        -1.995334           -1.153066
# 13519  19970105      1        -1.723721           -1.334652
# ...         ...    ...              ...                 ...
# 13875  19971227     12        -0.555784           -0.494815
# 13876  19971228     12        -0.868139           -0.937432
# 13877  19971229     12        -1.234817           -0.926083
# 13878  19971230     12        -1.139752           -0.892036
# 13879  19971231     12        -0.813817           -0.472117
#
#        BUDAPEST_temp_mean  DEBILT_temp_mean  DUSSELDORF_temp_mean  \
# 13515           -2.287267         -3.389558             -3.669680
# 13516           -1.875548         -3.579424             -3.728587
# 13517           -1.640280         -2.804135             -2.535730
# 13518           -1.275614         -2.234535             -2.300104
# 13519           -1.228561         -2.424402             -2.138111
# ...                   ...               ...                   ...
# 13875           -0.581573         -0.573200             -0.694901
# 13876           -0.675681         -0.747245             -0.783261
# 13877           -0.863895         -0.699778             -0.842167
# 13878           -0.993293         -0.699778             -0.694901
# 13879           -1.487355         -0.272578             -0.312009
#
#        GDANSK_temp_mean  HEATHROW_temp_mean  KASSEL_temp_mean  \
# 13515         -3.331811           -2.447619         -3.475840
# 13516         -1.950669           -2.395205         -3.239576
# 13517         -2.487780           -2.377734         -2.456949
# 13518         -3.037679           -2.080723         -2.250218
# 13519         -2.270378           -1.818653         -2.220685
# ...                 ...                 ...               ...
# 13875         -0.390490           -0.927619         -0.670199
# 13876         -0.761352           -1.259573         -0.891697
# 13877         -0.799717           -0.962561         -0.876931
# 13878         -1.004331           -0.578193         -0.847397
# 13879         -0.953178           -0.543251         -0.256736
#
#        LJUBLJANA_temp_mean  MAASTRICHT_temp_mean  MADRID_temp_mean  \
# 13515            -2.230563             -3.757828         -1.527444
# 13516            -1.939947             -3.232722         -1.500486
# 13517            -1.758312             -2.647603         -1.675714
# 13518            -1.395042             -2.302533         -1.635277
# 13519            -1.189189             -2.197511         -2.012691
# ...                    ...                   ...               ...
# 13875            -0.838028             -0.577182         -1.042197
# 13876            -1.055990             -0.787225         -1.406132
# 13877            -1.225516             -0.892246         -1.136550
# 13878            -1.140753             -0.652197         -0.840010
# 13879            -0.547412             -0.217109         -1.001760
#
#        MUNCHENB_temp_mean  OSLO_temp_mean  ROMA_temp_mean  \
# 13515           -2.465033       -2.176691       -0.522731
# 13516           -2.113146       -1.800510       -0.388025
# 13517           -1.786395       -2.455792       -0.219643
# 13518           -1.535047       -2.528601       -0.910009
# 13519           -1.409373       -2.043207       -1.246774
# ...                   ...             ...             ...
# 13875           -0.630196       -1.145228       -1.044715
# 13876           -0.843841       -0.987475       -1.465670
# 13877           -1.032352       -0.902531       -1.549861
# 13878           -0.969515       -0.914666       -1.330965
# 13879           -0.579927       -0.647699       -0.808980
#
#        SONNBLICK_temp_mean  STOCKHOLM_temp_mean  TOURS_temp_mean  \
# 13515            -1.440589            -1.747095        -3.159533
# 13516            -1.016461            -1.784417        -3.096782
# 13517            -0.826335            -1.995907        -2.610466
# 13518            -0.723959            -1.784417        -2.375151
# 13519            -1.074962            -1.274353        -2.328088
# ...                    ...                  ...              ...
# 13875            -0.957961            -1.050423        -0.727950
# 13876            -1.323588            -1.299234        -1.292705
# 13877            -1.499089            -0.702087        -0.790700
# 13878            -1.074962            -0.702087        -0.665199
# 13879            -0.548458            -0.639884        -0.476948
#
#        VALENTIA_temp_mean
# 13515           -3.071588
# 13516           -3.071588
# 13517           -3.852684
# 13518           -4.032937
# 13519           -3.251841
# ...                   ...
# 13875           -1.028721
# 13876           -1.239016
# 13877           -1.148890
# 13878           -0.397835
# 13879           -1.208974
#
# [365 rows x 20 columns]

# %%
df1997.describe()
# Out:
#                DATE       MONTH  BASEL_temp_mean  BELGRADE_temp_mean  \
# count  3.650000e+02  365.000000       365.000000          365.000000
# mean   1.997067e+07    6.526027         0.042657           -0.091439
# std    3.454755e+02    3.452584         0.983343            0.941042
# min    1.997010e+07    1.000000        -2.850915           -2.253933
# 25%    1.997040e+07    4.000000        -0.678010           -0.892036
# 50%    1.997070e+07    7.000000         0.109668           -0.165690
# 75%    1.997100e+07   10.000000         0.802281            0.833035
# max    1.997123e+07   12.000000         1.847992            1.854458
#
#        BUDAPEST_temp_mean  DEBILT_temp_mean  DUSSELDORF_temp_mean  \
# count          365.000000        365.000000            365.000000
# mean            -0.040231          0.042479             -0.015176
# std              0.990952          1.050227              1.023060
# min             -2.287267         -3.579424             -3.728587
# 25%             -0.863895         -0.652312             -0.724354
# 50%             -0.134564         -0.003600             -0.032203
# 75%              0.877089          0.850800              0.807215
# max              1.912268          2.353912              2.147338
#
#        GDANSK_temp_mean  HEATHROW_temp_mean  KASSEL_temp_mean  \
# count        365.000000          365.000000        365.000000
# mean          -0.011359            0.145787          0.016505
# std            1.016306            1.013425          1.086305
# min           -3.331811           -2.447619         -3.475840
# 25%           -0.774141           -0.578193         -0.744032
# 50%           -0.096358            0.068244         -0.050005
# 75%            0.875557            0.924336          0.939353
# max            2.128816            2.479279          2.268341
#
#        LJUBLJANA_temp_mean  MAASTRICHT_temp_mean  MADRID_temp_mean  \
# count           365.000000            365.000000        365.000000
# mean              0.011560              0.041725          0.098134
# std               0.945512              1.021010          0.874475
# min              -2.230563             -3.757828         -2.012691
# 25%              -0.801701             -0.652197         -0.624345
# 50%              -0.026725              0.037943          0.090047
# 75%               0.929886              0.803099          0.777480
# max               1.607991              2.228388          1.977119
#
#        MUNCHENB_temp_mean  OSLO_temp_mean  ROMA_temp_mean  \
# count          365.000000      365.000000      365.000000
# mean            -0.003032        0.097813        0.057888
# std              0.941932        1.049446        1.086399
# min             -2.465033       -2.528601       -1.735082
# 25%             -0.768437       -0.671969       -0.910009
# 50%             -0.014395       -0.065226       -0.169128
# 75%              0.815052        0.990506        1.127414
# max              1.707336        2.009833        2.104030
#
#        SONNBLICK_temp_mean  STOCKHOLM_temp_mean  TOURS_temp_mean  \
# count           365.000000           365.000000       365.000000
# mean              0.020999             0.055255         0.081016
# std               0.888661             1.033103         1.019173
# min              -1.996343            -2.219837        -3.159533
# 25%              -0.665459            -0.776730        -0.602449
# 50%              -0.036580            -0.129820         0.087807
# 75%               0.811676             0.877867         0.840813
# max               1.791557             2.059722         2.158574
#
#        VALENTIA_temp_mean
# count          365.000000
# mean             0.278977
# std              1.187601
# min             -4.032937
# 25%             -0.457920
# 50%              0.323176
# 75%              1.164357
# max              3.057013

# %%
#Reduce your dataset to a single year
df2019 = df[df['DATE'].astype(str).str.contains('2019')] #<-----INSERT YEAR HERE
df2019
# Out:
#            DATE  MONTH  BASEL_temp_mean  BELGRADE_temp_mean  \
# 21550  20190101      1        -0.732333           -1.232510
# 21551  20190102      1        -0.963204           -1.107669
# 21552  20190103      1        -1.452108           -1.527588
# 21553  20190104      1        -1.424946           -1.856713
# 21554  20190105      1        -1.126172           -1.731872
# ...         ...    ...              ...                 ...
# 21910  20191227     12        -0.487881           -1.084971
# 21911  20191228     12        -0.908881           -1.209812
# 21912  20191229     12        -1.520011           -1.368700
# 21913  20191230     12        -1.343462           -1.607032
# 21914  20191231     12        -1.357043           -1.538937
#
#        BUDAPEST_temp_mean  DEBILT_temp_mean  DUSSELDORF_temp_mean  \
# 21550           -1.052110         -0.367511             -0.562362
# 21551           -0.993293         -0.731423             -0.989434
# 21552           -1.475592         -0.952934             -1.048340
# 21553           -1.534409         -0.778890             -1.151427
# 21554           -1.216797         -0.478267             -0.709628
# ...                   ...               ...                   ...
# 21910           -0.863895         -1.063690             -0.945254
# 21911           -1.110927         -1.601646             -1.490139
# 21912           -1.287378         -1.395957             -1.225060
# 21913           -1.299141         -0.858001             -0.901074
# 21914           -1.063873         -0.921290             -1.269240
#
#        GDANSK_temp_mean  HEATHROW_temp_mean  KASSEL_temp_mean  \
# 21550         -0.352125           -0.595665         -0.005705
# 21551         -0.786929           -1.084860         -0.005705
# 21552         -0.953178           -1.102331         -0.005705
# 21553         -0.978754           -1.434286         -0.005705
# 21554         -0.607892           -1.259573         -0.005705
# ...                 ...                 ...               ...
# 21910         -0.595104           -0.648078         -0.005705
# 21911         -0.722987           -0.543251         -0.005705
# 21912         -0.799717           -0.438423         -0.005705
# 21913         -0.556739           -0.822791         -0.005705
# 21914         -0.237030           -0.717963         -0.005705
#
#        LJUBLJANA_temp_mean  MAASTRICHT_temp_mean  MADRID_temp_mean  \
# 21550            -1.031772             -0.592185         -1.123071
# 21551            -1.043881             -1.042277         -1.203946
# 21552            -1.104426             -1.042277         -1.028718
# 21553            -1.395042             -1.147298         -1.217425
# 21554            -1.479805             -0.757219         -1.284820
# ...                    ...                   ...               ...
# 21910            -0.934900             -0.697206         -0.813052
# 21911            -1.213407             -1.237316         -0.907406
# 21912            -1.467696             -1.357341         -0.961322
# 21913            -1.576677             -0.772222         -1.069155
# 21914            -1.334497             -1.087286         -1.096113
#
#        MUNCHENB_temp_mean  OSLO_temp_mean  ROMA_temp_mean  \
# 21550           -0.617629       -0.210845       -0.000746
# 21551           -1.082622       -0.659834       -0.000746
# 21552           -1.371671       -0.659834       -0.000746
# 21553           -1.271132       -0.502081       -0.000746
# 21554           -1.132891       -0.380732       -0.000746
# ...                   ...             ...             ...
# 21910           -0.667898       -1.375790       -0.000746
# 21911           -1.145458       -0.926801       -0.000746
# 21912           -1.333969       -0.247249       -0.000746
# 21913           -1.132891       -0.113766       -0.000746
# 21914           -0.755870       -0.647699       -0.000746
#
#        SONNBLICK_temp_mean  STOCKHOLM_temp_mean  TOURS_temp_mean  \
# 21550            -0.533833            -0.391072        -0.712262
# 21551            -1.382089            -1.037982        -0.916201
# 21552            -2.508221            -1.212150        -1.324080
# 21553            -2.230344            -0.577681        -1.449581
# 21554            -1.528340            -0.838933        -1.433893
# ...                    ...                  ...              ...
# 21910            -0.884835            -1.013101        -0.084757
# 21911            -1.294338            -1.174829        -0.461260
# 21912            -1.440589            -0.565240        -1.277017
# 21913            -0.738584             0.094110        -1.449581
# 21914            -0.051205            -0.366191        -1.512331
#
#        VALENTIA_temp_mean
# 21550           -0.007287
# 21551           -0.007287
# 21552           -0.007287
# 21553           -0.007287
# 21554           -0.007287
# ...                   ...
# 21910           -0.007287
# 21911           -0.007287
# 21912           -0.007287
# 21913           -0.007287
# 21914           -0.007287
#
# [365 rows x 20 columns]

# %%
df2019.describe()
# Out:
#                DATE       MONTH  BASEL_temp_mean  BELGRADE_temp_mean  \
# count  3.650000e+02  365.000000       365.000000          365.000000
# mean   2.019067e+07    6.526027         0.170502            0.282088
# std    3.454755e+02    3.452584         0.976797            0.942994
# min    2.019010e+07    1.000000        -1.669398           -1.924808
# 25%    2.019040e+07    4.000000        -0.555784           -0.404022
# 50%    2.019070e+07    7.000000         0.096087            0.333672
# 75%    2.019100e+07   10.000000         0.897346            1.003272
# max    2.019123e+07   12.000000         2.540605            2.070092
#
#        BUDAPEST_temp_mean  DEBILT_temp_mean  DUSSELDORF_temp_mean  \
# count          365.000000        365.000000            365.000000
# mean             0.269420          0.184273              0.169048
# std              0.963701          0.942226              0.986419
# min             -1.699097         -1.997201             -2.093931
# 25%             -0.463939         -0.525734             -0.577088
# 50%              0.206575          0.091333              0.026704
# 75%              1.053540          0.914089              0.895575
# max              2.100483          2.970979              3.016209
#
#        GDANSK_temp_mean  HEATHROW_temp_mean  KASSEL_temp_mean  \
# count        365.000000          365.000000      3.650000e+02
# mean           0.244828            0.172018     -5.705221e-03
# std            0.910151            0.975865      4.777038e-17
# min           -2.027399           -2.028309     -5.705221e-03
# 25%           -0.480009           -0.595665     -5.705221e-03
# 50%            0.121044            0.068244     -5.705221e-03
# 75%            1.016229            0.976750     -5.705221e-03
# max            2.282276            3.073302     -5.705221e-03
#
#        LJUBLJANA_temp_mean  MAASTRICHT_temp_mean  MADRID_temp_mean  \
# count           365.000000            365.000000        365.000000
# mean              0.224877              0.194509          0.163277
# std               0.960609              0.968814          1.025720
# min              -1.782530             -2.047481         -1.743109
# 25%              -0.474758             -0.562179         -0.718699
# 50%               0.154910              0.127961         -0.044744
# 75%               1.075195              0.908120          0.912271
# max               2.225550              3.113568          2.354534
#
#        MUNCHENB_temp_mean  OSLO_temp_mean  ROMA_temp_mean  \
# count          365.000000      365.000000    3.650000e+02
# mean             0.250347        0.105426   -7.461638e-04
# std              0.938443        0.914662    4.559900e-18
# min             -1.685856       -2.067477   -7.461638e-04
# 25%             -0.479388       -0.587025   -7.461638e-04
# 50%              0.199251        0.007583   -7.461638e-04
# 75%              0.953293        0.941966   -7.461638e-04
# max              2.360839        2.288935   -7.461638e-04
#
#        SONNBLICK_temp_mean  STOCKHOLM_temp_mean  TOURS_temp_mean  \
# count           365.000000           365.000000       365.000000
# mean              0.190690             0.156688         0.244511
# std               1.031892             0.920464         0.997437
# min              -2.508221            -1.747095        -1.731958
# 25%              -0.533833            -0.540359        -0.476948
# 50%               0.080421             0.031908         0.087807
# 75%               1.104177             0.927629         0.934939
# max               2.464311             2.271212         3.037082
#
#        VALENTIA_temp_mean
# count        3.650000e+02
# mean        -7.287352e-03
# std          4.603327e-17
# min         -7.287352e-03
# 25%         -7.287352e-03
# 50%         -7.287352e-03
# 75%         -7.287352e-03
# max         -7.287352e-03

# %%
#Pick which weather station you want to use. Below is a 3D visualization of the temperatures for that year.

# %%
#Drop the DATE and MONTH data as those numbers are not scaled with the rest.
df1970 = df1970.drop(['DATE','MONTH'], axis=1)

# %%
#Plot ALL weather data for all stations for a year 

#X = weather station
#Y = day of the year
#Z = temperature

#you can click/hold in the graph below to rotate!

fig = go.Figure(data=[go.Surface(z=df1970.values)])
fig.update_layout(title='Temperatures over time', autosize=False,
                  width=600, height=600)
fig.show()
# Out:
# <div>                            <div id="d49304ff-e1a0-478a-a7ae-7ed9711ed772" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d49304ff-e1a0-478a-a7ae-7ed9711ed772")) {                    Plotly.newPlot(                        "d49304ff-e1a0-478a-a7ae-7ed9711ed772",                        [{"z":[[-1.900269194076148,-1.3800488276500995,-1.4167750545422917,-3.0889352973490505,-2.889168909898671,-3.3573881751860903,-1.923481079161598,-2.6784473420217867,-1.4555870929768018,-2.842642403831916,-1.392653111022763,-1.7989619593037276,-1.2544418201171357,-1.179420854877844,-1.5283395976373453,-1.6600111817919692,-2.1398366450172963,-2.260449715153127],[-1.9681724704165635,-1.6297300562573998,-1.5814626992647445,-1.4908899189848444,-1.6668586972004644,-1.809997329198404,-1.6264694784391815,-1.8958211962007716,-1.6735491446837938,-1.7924289734881995,-1.810504898859106,-1.6858555843259302,-1.6548919490617084,-1.566699681942982,-1.7915913014611289,-1.5356053956830364,-1.857459283193656,-1.809817242550955],[-1.7101400203229855,-1.300604800365959,-1.934364795098573,-1.6174677707364644,-1.4754125193079743,-1.4519234144243935,-1.6439407490699118,-1.526657919870104,-1.4313690872315803,-1.3873466503556229,-1.5004858304643995,-1.283699584404873,-1.909723849299164,-1.2467736943674332,-1.221212609842931,-1.9710256470643013,-1.7476458647066844,-1.5995220886699415],[-1.5200108465698228,-0.9260829574550088,-1.7343869407927368,-2.171245872149804,-2.079204311122751,-1.5414418931178964,-2.2729064917762054,-1.940120789360452,-1.0438809953080384,-1.9874686105520325,-0.6378240749313034,-1.4596428343703356,-2.3587133878127755,-1.027876966026268,-1.060336568617286,-2.070550275951448,-2.030023226530325,-2.6509978580750087],[-1.1125911885273307,-0.4494187937501631,-1.0521095555140023,-1.9813790945223728,-1.902484762298914,-1.4647117685234656,-2.430147927452779,-1.733389354615278,-1.0196629895628169,-1.8524411695078404,-0.7321777044427358,-1.283699584404873,-2.492196764127633,-0.2533193118959919,-0.6215837289109803,-2.854306728437724,-1.998647964105476,-2.560871363554574],[-1.8595272282718984,-0.9147338107001314,-1.0050559427361585,-1.7440456224880847,-1.5637722937198928,-1.630960371811399,-2.0981937854689017,-1.6447901682959176,-1.128644015416313,-1.6123923854292763,-0.8534895138145775,-1.899500959283992,-2.7470286643650894,-0.4553778303647598,-0.7532095808228718,-3.115558879266483,-2.8928429432136715,-2.560871363554574],[-1.927430504612314,-1.3686996808952223,-1.2285606034309164,-2.234534798025613,-1.7846717297496892,-1.7460555587030449,-2.168078867991823,-1.526657919870104,-1.382933075741137,-1.5523801894096354,-0.9343640533958052,-1.7863945843061944,-2.977590859818025,-1.0110387561538707,-1.5429646922942215,-2.854306728437724,-2.8928429432136715,-2.3205340448334164],[-1.8187852624676497,-1.6183809095025223,-1.7108601344038148,-2.0288457889292304,-1.7993983588183422,-1.1705796242448143,-1.818653455377216,-1.9105877272539984,-1.8672931906455648,-1.8074320224931093,-0.5704286252802804,-2.037742084256855,-2.1402860447521,-1.1625826450054466,-1.13346204190167,-1.9088227540098348,-1.6064571837948638,-1.058763121547336],[-1.3163010175485768,-1.720523230296418,-2.0872890366265646,-1.4434232245779866,-1.3281462286214436,-1.861150745594691,-1.1547451714094616,-1.526657919870104,-1.709876153301626,-0.9072490821984954,-0.7456567943729404,-1.8115293343012608,-1.509273720354591,-1.0952298055158574,0.0219204359916011,-1.9337039112316208,-0.6965745734742439,-0.9986787918670466],[-1.139752499063497,-1.4254454146696087,-1.9814184078764163,-1.269378678419509,-1.0925201635229942,-2.027399348882624,-0.8577335706870454,-1.2903934230184768,-1.5887861245755193,-0.7572185921493931,-0.9208849634656008,-1.6481534593333311,-1.5456782775313702,-0.77 ...

# %%
#Drop the DATE and MONTH data as those numbers are not scaled with the rest.
df1997 = df1997.drop(['DATE','MONTH'], axis=1)

# %%
#Plot ALL weather data for all stations for a year 

#X = weather station
#Y = day of the year
#Z = temperature

#you can click/hold in the graph below to rotate!

fig = go.Figure(data=[go.Surface(z=df1997.values)])
fig.update_layout(title='Temperatures over time', autosize=False,
                  width=600, height=600)
fig.show()
# Out:
# <div>                            <div id="2d2c347c-8e73-452e-babb-31064c8ec53a" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d2c347c-8e73-452e-babb-31064c8ec53a")) {                    Plotly.newPlot(                        "2d2c347c-8e73-452e-babb-31064c8ec53a",                        [{"z":[[-2.850915062841961,-1.9021095783744544,-2.287266890932401,-3.3895576952591484,-3.669680250537284,-3.331811466987947,-2.4476191980835087,-3.475840018896029,-2.230563276823885,-3.75782839313144,-1.5274440103248088,-2.4650328341729777,-2.176690601928879,-0.5227306698543488,-1.440589029696084,-1.7470952320682225,-3.1595326738248874,-3.0715881658370354],[-2.8373344075738784,-1.7318723770512952,-1.875547779126268,-3.5794244728865787,-3.7285867668118966,-1.9506692242881936,-2.395205386191318,-3.239575522044401,-1.939947207881229,-3.232721677959582,-1.5004858304643995,-2.1131463342420536,-1.800510177768826,-0.3880249908751705,-1.0164612846466552,-1.784416967900902,-3.0967821489751897,-3.0715881658370354],[-2.253366231046308,-1.3460013873854677,-1.6402797152370494,-2.804135130907905,-2.5357298122509966,-2.487780096449209,-2.377734115560588,-2.456949376223386,-1.7583121647920688,-2.6476027667680824,-1.6757139995570598,-1.7863945843061944,-2.4557922069508544,-0.2196428921511974,-0.826335054107256,-1.995906804286088,-2.6104655813900304,-3.852684451680799],[-1.9953337809527287,-1.153065892552554,-1.2756142162087605,-2.234534798025613,-2.300103747152547,-3.0376793227092955,-2.080722514838171,-2.2502179414782124,-1.3950420786137483,-2.3025326396551478,-1.635276729766446,-1.5350470843555335,-2.528601321304413,-0.910009496919487,-0.7239593915091183,-1.784416967900902,-2.375151113203664,-4.0329374407216685],[-1.723720675591068,-1.3346522406305903,-1.2285606034309164,-2.4244015756530435,-2.138110827397363,-2.270378076764988,-1.818653455377216,-2.220684879371759,-1.1891890297793666,-2.1975112966207755,-2.0126912478121755,-1.4093733343802035,-2.043207225614021,-1.2467736943674332,-1.0749616632741628,-1.2743532448542776,-2.32808821956639,-3.251841154877904],[-1.8595272282718984,-1.3346522406305903,-1.5344090864869009,-2.835779593845809,-2.653542844800221,-1.503076830820681,-1.6788832903313728,-2.4717159072766126,-1.1891890297793666,-2.43756008069934,-1.6487558196966503,-1.4470754593728026,-1.8611844397301247,-1.347802953601817,-1.1627122312154237,-1.4982836598503568,-2.0770861201675985,-2.4407027041939955],[-1.9817531256846463,-1.5048894419537495,-1.4873554737090573,-2.4244015756530435,-2.8155357645554053,-1.669325434108614,-2.0981937854689017,-2.648914279915333,-1.3344970642506948,-2.587590570748442,-1.8374630787195152,-1.9749052092691897,-2.079611782790801,-1.1457444351330497,-1.031086379303532,-1.3987590309632103,-2.547715056540333,-2.1703232206326923],[-1.927430504612314,-1.448143708179363,-1.369721441764448,-2.788312899438952,-2.992255313379242,-2.052976057080768,-2.2554352211454747,-2.5898481557024264,-1.4192600843589696,-2.752624109802454,-1.4196112908831715,-1.9120683342815248,-2.188825454321139,-1.1962590647502411,-1.060336568617286,-1.4485213454067836,-2.296712957141541,-2.681040022915153],[-1.9138498493442315,-1.277906506856204,-1.7932039567650415,-2.693379510625237,-2.7713558773494458,-1.9123041619909784,-2.02830870294598,-2.264984472531439,-1.4313690872315803,-2.5125753257238905,-0.799573154093759,-1.6732882093283974,-2.006802668437242,-0.8258184475575004,-1.0018361899897783,-1.3116749806869576,-1.7947087583439578,-2.0501545612721133],[-1.886688538808065,-1.2325099198366951,-1.369721441764448,-2.1237791777429456,-2.1528374564660164,-1.8483623914956195,-1.8885385379001367,-1.8810546651475448,-1.310279058505473,-2.272526541645327,-0.866968603744782,-1.585316584345666,-2.346578535420516,-1.1120680153882545,-0. ...

# %%
#Drop the DATE and MONTH data as those numbers are not scaled with the rest.
df2019 = df2019.drop(['DATE','MONTH'], axis=1)

# %%
#Plot ALL weather data for all stations for a year 

#X = weather station
#Y = day of the year
#Z = temperature

#you can click/hold in the graph below to rotate!

fig = go.Figure(data=[go.Surface(z=df2019.values)])
fig.update_layout(title='Temperatures over time', autosize=False,
                  width=600, height=600)
fig.show()
# Out:
# <div>                            <div id="ded25689-e71c-4606-8f37-88df39ffa792" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ded25689-e71c-4606-8f37-88df39ffa792")) {                    Plotly.newPlot(                        "ded25689-e71c-4606-8f37-88df39ffa792",                        [{"z":[[-0.7323328410210055,-1.2325099198366951,-1.0521095555140023,-0.3675114846892142,-0.562361517051483,-0.3521249619042197,-0.5956645112260899,-0.0057052213877543,-1.0317719924354278,-0.5921850530953804,-1.12307131241867,-0.6176287095356227,-0.2108445143827938,-0.0007461638100323,-0.533833160969719,-0.391072163480855,-0.7122622046866685,-0.0072873521422696],[-0.9632039805784174,-1.107669305533045,-0.9932925395416978,-0.7314228084751225,-0.9894337600424224,-0.7869290012726606,-1.08486008888654,-0.0057052213877543,-1.0438809953080384,-1.0422765232426876,-1.2039458519998978,-1.0826215844443448,-0.659834052896406,-0.0007461638100323,-1.3820886510685766,-1.0379822512473054,-0.9162014104481868,-0.0072873521422696],[-1.4521075702294075,-1.5275877354635043,-1.4755920705145964,-0.952934049040458,-1.0483402763170349,-0.953177604560594,-1.1023313595172706,-0.0057052213877543,-1.1044260096710918,-1.0422765232426876,-1.0287176829072375,-1.3716712093876045,-0.659834052896406,-0.0007461638100323,-2.508220939648094,-1.2121503517998111,-1.324079821971223,-0.0072873521422696],[-1.4249462596932412,-1.8567129913549452,-1.5344090864869009,-0.7788895028819802,-1.1514266797976065,-0.9787543127587376,-1.4342855015011475,-0.0057052213877543,-1.3950420786137483,-1.1472978662770592,-1.2174249419301024,-1.27113220940734,-0.5020809717970287,-0.0007461638100323,-2.2303441411674343,-0.5776808426442541,-1.449580871670619,-0.0072873521422696],[-1.126171843795414,-1.7318723770512952,-1.2167972002364555,-0.478267104971882,-0.7096278077380138,-0.6078920438856555,-1.2595727951938438,-0.0057052213877543,-1.479805098722023,-0.7572185921493931,-1.2848203915811256,-1.1328910844344768,-0.3807324478744309,-0.0007461638100323,-1.5283395976373453,-0.8389329934730131,-1.4338932404581946,-0.0072873521422696],[-0.9224620147741682,-1.4140962679147315,-1.2050337970419946,-0.6206671881924549,-0.7538076949439732,-1.1322145619475992,-0.7179634056412024,-0.0057052213877543,-1.310279058505473,-0.877242984188675,-1.12307131241867,-0.9820825844640804,-0.9025311007416016,-0.0007461638100323,-1.2797129884704388,-0.8016112576403331,-1.1672035098469784,-0.0072873521422696],[-1.0175266016507496,-1.9248078718842088,-1.6285163120425885,-0.5257337993787395,-0.8716207274931979,-1.081061145551312,-0.4558943461802469,-0.0057052213877543,-1.3708240728685268,-0.7422155431444828,-1.055675862767647,-0.9569478344690144,-0.9025311007416016,-0.0007461638100323,-1.3089631777841924,-0.6523243143096138,-0.8534508855984887,-0.0072873521422696],[-0.854558738433753,-1.8794112848647,-1.687333328014893,-0.4624448735029295,-0.6212680333260954,-0.9276008963624504,-0.6131357818568202,-0.0057052213877543,-1.3950420786137483,-0.6521972491150214,-1.055675862767647,-0.8438414594912171,-0.6234294957196266,-0.0007461638100323,-1.060336568617286,-0.7767301004185465,-0.5553858925624237,-0.0072873521422696],[-1.2076557754039123,-1.1984624795720633,-1.6285163120425885,-0.8105339658198851,-1.0041603891110755,-0.953177604560594,-1.277044065824574,-0.0057052213877543,-1.4313690872315803,-1.012270425232867,-0.9882804131166236,-1.1580258344295429,-0.7447780196422245,-0.0007461638100323,-1.806216396118005,-0.8264924148621197,-1.1672035098469784,-0.0072873521422696],[-1.397784949157075,-1.436794561424486,-1.4403018609312137,-1.1111563637299833,-1.431232632102015,-1.2345213947401732,-1.2945153364553046,-0.0057052213877543,-1.237625041269809,-1.3573405523458026,-1.379174021092558,-1.2962669594024063,-1.03 ...

# %%
#We need to make an index for the year. Create a set of data from 1 to 365 (or to 366 if it's a leap year!)
#We'll scale this by 100 as the index is made. This will help teh gradient descent converge 366 = 3.66

i = np.arange(0.01,3.66,0.01) #<---needs to be one GREATER than the total number of days
index = pd.DataFrame(data = i, columns = ['index'])
index
# Out:
#      index
# 0     0.01
# 1     0.02
# 2     0.03
# 3     0.04
# 4     0.05
# ..     ...
# 360   3.61
# 361   3.62
# 362   3.63
# 363   3.64
# 364   3.65
#
# [365 rows x 1 columns]

# %%
n_rows = df1970.shape[0]
n_rows
# Out:
# 365

# %% [markdown]
# ## Heathrow 1970

# %%
#This will translate your chosen weather data into the X and y datasets needed for the optimization function.

X=index.to_numpy().reshape(n_rows,1)
#Represent x_0 as a vector of 1s for vector computation
ones = np.ones((n_rows,1))
X = np.concatenate((ones, X), axis=1)
y=df1970['HEATHROW_temp_mean'].to_numpy().reshape(n_rows,1) #<----INSERT WEATHER STATION HERE

# %%
X.shape, y.shape
# Out:
# ((365, 2), (365, 1))

# %%
#Look at one year of temperature data over time
plt.scatter(x=index['index'], y=df1970['HEATHROW_temp_mean']) #<----INSERT WEATHER STATION HERE
plt.xlabel('X'); plt.ylabel('y');
plt.title('Input dataset');
plt.show()

# %%
#what is the min temperature? (Note gradient descent is not actually finding this number)
df1970['HEATHROW_temp_mean'].min()
# Out:
# -2.430147927452779

# %%
#what is the max temperature? (Note gradient descent is not actually finding this number)
df1970['HEATHROW_temp_mean'].max()
# Out:
# 2.23468133095223

# %%
#loss function for the gradient descent
def compute_cost(X, y, theta=np.array([[0],[0]])):
    """Given covariate matrix X, the prediction results y and coefficients theta
    compute the loss"""
    
    m = len(y)
    J=0 # initialize loss to zero
    
    # reshape theta
    theta=theta.reshape(2,1)
    
    # calculate the hypothesis - y_hat
    h_x = np.dot(X,theta)
    #print(h_x)
    
    # subtract y from y_hat, square and sum
    error_term = sum((h_x - y)**2)
    
    # divide by twice the number of samples - standard practice.
    loss = error_term/(2*m)
    
    return loss

# %%
compute_cost(X,y)
# Out:
# array([0.56978027])

# %%
#gradiant descent function
def gradient_descent(X, y, theta=np.array([[0],[0]]),
                    alpha=0.01, num_iterations=1500):
    """
    Solve for theta using Gradient Descent optimiztion technique. 
    Alpha is the learning rate
    """
    m = len(y)
    J_history = []
    theta0_history = []
    theta1_history = []
    theta = theta.reshape(2,1)
    
    for i in range(num_iterations):
        error = (np.dot(X, theta) - y)
        
        term0 = (alpha/m) * sum(error* X[:,0].reshape(m,1))
        term1 = (alpha/m) * sum(error* X[:,1].reshape(m,1))
        
        # update theta
        term_vector = np.array([[term0],[term1]])
        #print(term_vector)
        theta = theta - term_vector.reshape(2,1)
        
        # store history values
        theta0_history.append(theta[0].tolist()[0])
        theta1_history.append(theta[1].tolist()[0])
        J_history.append(compute_cost(X,y,theta).tolist()[0])
        
    return (theta, J_history, theta0_history, theta1_history)

# %%
#Run data through a gradiant descent for the starting conditions in 'theta_init'.

num_iterations=100 
theta_init=np.array([[0.5],[1]]) 
alpha=0.01 
theta, J_history, theta0_history, theta1_history = gradient_descent(X,y, theta_init,
                                                                   alpha, num_iterations)

# %%
theta
# Out:
# array([[-0.0580304],
#        [ 0.0517507]])

# %%
#Plot loss, theta0, and theta1.

fig, ax1 = plt.subplots()

# plot thetas over time
color='tab:blue'
ax1.plot(theta0_history, label='$\\theta_{0}$', linestyle='--', color=color)
ax1.plot(theta1_history, label='$\\theta_{1}$', linestyle='-', color=color)
# ax1.legend()
ax1.set_xlabel('Iterations'); ax1.set_ylabel('$\\theta$', color=color);
ax1.tick_params(axis='y', labelcolor=color)

# plot loss function over time
color='tab:red'
ax2 = ax1.twinx()
ax2.plot(J_history, label='Loss function', color=color)
ax2.set_title('Values of $\\theta$ and $J(\\theta)$ over iterations')
ax2.set_ylabel('Loss: $J(\\theta)$', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# ax2.legend();
fig.legend();

plt.show()

# %%
# %%time
# theta range
theta0_vals = np.linspace(-10,10,100) #Look in the chart above for the limits of where theta0 and theta1 appear.
theta1_vals = np.linspace(-10,10,100) #Put those values as the first two "linspace" numbers in these lines
                                      #Select with large margins, maybe +/- 10
J_vals = np.zeros((len(theta0_vals), len(theta1_vals)))

# compute cost for each combination of theta
c1=0; c2=0
for i in theta0_vals:
    for j in theta1_vals:
        t = np.array([i, j])
        J_vals[c1][c2] = compute_cost(X, y, t.transpose()).tolist()[0]
        c2=c2+1
    c1=c1+1
    c2=0 # reinitialize to 0
# Out:
# CPU times: total: 2.88 s
# Wall time: 3.72 s

# %%
#This figure shows the loss function.

#X = Theta0
#Y - Theta1
#Z = Loss
#Find where it is closest to 0 in X and Y!

#you can click/hold in the graph below to rotate!

fig = go.Figure(data=[go.Surface(x=theta1_vals, y=theta0_vals, z=J_vals)])
fig.update_layout(title='Loss function for different thetas', autosize=True,
                  width=600, height=600, xaxis_title='theta0', 
                 yaxis_title='theta1')
fig.show()
# Out:
# <div>                            <div id="d428dcaa-1051-4e33-a00c-cd92c0306cd1" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d428dcaa-1051-4e33-a00c-cd92c0306cd1")) {                    Plotly.newPlot(                        "d428dcaa-1051-4e33-a00c-cd92c0306cd1",                        [{"x":[-10.0,-9.797979797979798,-9.595959595959595,-9.393939393939394,-9.191919191919192,-8.98989898989899,-8.787878787878787,-8.585858585858587,-8.383838383838384,-8.181818181818182,-7.979797979797979,-7.777777777777778,-7.575757575757576,-7.373737373737374,-7.171717171717171,-6.96969696969697,-6.767676767676768,-6.565656565656566,-6.363636363636363,-6.161616161616162,-5.959595959595959,-5.757575757575758,-5.555555555555555,-5.353535353535354,-5.151515151515151,-4.94949494949495,-4.747474747474747,-4.545454545454546,-4.343434343434343,-4.141414141414142,-3.9393939393939394,-3.737373737373738,-3.5353535353535355,-3.333333333333333,-3.1313131313131315,-2.929292929292929,-2.7272727272727275,-2.525252525252525,-2.3232323232323235,-2.121212121212121,-1.9191919191919187,-1.717171717171718,-1.5151515151515156,-1.3131313131313131,-1.1111111111111107,-0.9090909090909101,-0.7070707070707076,-0.5050505050505052,-0.30303030303030276,-0.10101010101010033,0.10101010101010033,0.30303030303030276,0.5050505050505052,0.7070707070707076,0.9090909090909083,1.1111111111111107,1.3131313131313131,1.5151515151515156,1.7171717171717162,1.9191919191919187,2.121212121212121,2.3232323232323235,2.525252525252524,2.7272727272727266,2.929292929292929,3.1313131313131315,3.333333333333334,3.5353535353535346,3.737373737373737,3.9393939393939394,4.141414141414142,4.3434343434343425,4.545454545454545,4.747474747474747,4.94949494949495,5.1515151515151505,5.353535353535353,5.555555555555555,5.757575757575758,5.9595959595959584,6.161616161616163,6.363636363636363,6.565656565656564,6.767676767676768,6.969696969696969,7.171717171717173,7.373737373737374,7.575757575757574,7.777777777777779,7.979797979797979,8.18181818181818,8.383838383838384,8.585858585858585,8.787878787878789,8.98989898989899,9.19191919191919,9.393939393939394,9.595959595959595,9.7979797979798,10.0],"y":[-10.0,-9.797979797979798,-9.595959595959595,-9.393939393939394,-9.191919191919192,-8.98989898989899,-8.787878787878787,-8.585858585858587,-8.383838383838384,-8.181818181818182,-7.979797979797979,-7.777777777777778,-7.575757575757576,-7.373737373737374,-7.171717171717171,-6.96969696969697,-6.767676767676768,-6.565656565656566,-6.363636363636363,-6.161616161616162,-5.959595959595959,-5.757575757575758,-5.555555555555555,-5.353535353535354,-5.151515151515151,-4.94949494949495,-4.747474747474747,-4.545454545454546,-4.343434343434343,-4.141414141414142,-3.9393939393939394,-3.737373737373738,-3.5353535353535355,-3.333333333333333,-3.1313131313131315,-2.929292929292929,-2.7272727272727275,-2.525252525252525,-2.3232323232323235,-2.121212121212121,-1.9191919191919187,-1.717171717171718,-1.5151515151515156,-1.3131313131313131,-1.1111111111111107,-0.9090909090909101,-0.7070707070707076,-0.5050505050505052,-0.30303030303030276,-0.10101010101010033,0.10101010101010033,0.30303030303030276,0.5050505050505052,0.7070707070707076,0.9090909090909083,1.1111111111111107,1.3131313131313131,1.5151515151515156,1.7171717171717162,1.9191919191919187,2.121212121212121,2.3232323232323235,2.525252525252524,2.7272727272727266,2.929292929292929,3.1313131313131315,3.333333333333334,3.5353535353535346,3.737373737373737,3.9393939393939394,4.141414141414142,4.3434343434343425,4.545454545454545,4.747474747474747,4.94949494949495,5.1515151515151505,5.353535353535353,5.555555555555555,5.757575757575758,5.9595959595959584,6.161616161616163,6.363636363636363,6.565656565656564,6.767676767676768,6.969696969696969,7.1717 ...

# %% [markdown]
# ## Heathrow 1997

# %%
#This will translate your chosen weather data into the X and y datasets needed for the optimization function.

X=index.to_numpy().reshape(n_rows,1)
#Represent x_0 as a vector of 1s for vector computation
ones = np.ones((n_rows,1))
X = np.concatenate((ones, X), axis=1)
y=df1997['HEATHROW_temp_mean'].to_numpy().reshape(n_rows,1) #<----INSERT WEATHER STATION HERE

# %%
X.shape, y.shape
# Out:
# ((365, 2), (365, 1))

# %%
#Look at one year of temperature data over time
plt.scatter(x=index['index'], y=df1997['HEATHROW_temp_mean']) #<----INSERT WEATHER STATION HERE
plt.xlabel('X'); plt.ylabel('y');
plt.title('Input dataset');
plt.show()

# %%
#what is the min temperature? (Note gradient descent is not actually finding this number)
df1997['HEATHROW_temp_mean'].min()
# Out:
# -2.4476191980835087

# %%
#what is the max temperature? (Note gradient descent is not actually finding this number)
df1997['HEATHROW_temp_mean'].max()
# Out:
# 2.479279119782455

# %%
#Run data through a gradiant descent for the starting conditions in 'theta_init'.

num_iterations=100 
theta_init=np.array([[0.5],[1]]) 
alpha=0.01 
theta, J_history, theta0_history, theta1_history = gradient_descent(X,y, theta_init,
                                                                   alpha, num_iterations)

# %%
#Plot loss, theta0, and theta1.

fig, ax1 = plt.subplots()

# plot thetas over time
color='tab:blue'
ax1.plot(theta0_history, label='$\\theta_{0}$', linestyle='--', color=color)
ax1.plot(theta1_history, label='$\\theta_{1}$', linestyle='-', color=color)
# ax1.legend()
ax1.set_xlabel('Iterations'); ax1.set_ylabel('$\\theta$', color=color);
ax1.tick_params(axis='y', labelcolor=color)

# plot loss function over time
color='tab:red'
ax2 = ax1.twinx()
ax2.plot(J_history, label='Loss function', color=color)
ax2.set_title('Values of $\\theta$ and $J(\\theta)$ over iterations')
ax2.set_ylabel('Loss: $J(\\theta)$', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# ax2.legend();
fig.legend();

plt.show()

# %%
# theta range
theta0_vals = np.linspace(.2,.7,10) 
theta1_vals = np.linspace(-.3,.7,10) 

J_vals = np.zeros((len(theta0_vals), len(theta1_vals)))

# compute cost for each combination of theta
c1=0; c2=0
for i in theta0_vals:
    for j in theta1_vals:
        t = np.array([i, j])
        J_vals[c1][c2] = compute_cost(X, y, t.transpose()).tolist()[0]
        c2=c2+1
    c1=c1+1
    c2=0

# %%
#Loss Function Figure

#X = Theta0
#Y - Theta1
#Z = Loss
#black line = path of loss function over the iterations.
#Find where it is closest to 0 in X and Y!

line_marker = dict(color='#101010', width=2)
fig = go.Figure()
fig.add_surface(x=theta1_vals, y=theta0_vals, z=J_vals)
fig.add_scatter3d(x=theta1_history, y=theta0_history, z=J_history, line=line_marker, name='')
#The below line adds a graph of just the loss over iterations in a 2D plane
plt.plot(theta0_history, theta1_history, 'r+');
fig.update_layout(title='Loss function for different thetas', autosize=True,
                  width=600, height=600, xaxis_title='theta0', 
                 yaxis_title='theta1')
fig.show()
# Out:
# <div>                            <div id="aaf57605-f08f-42c9-a8a4-e5699e075606" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aaf57605-f08f-42c9-a8a4-e5699e075606")) {                    Plotly.newPlot(                        "aaf57605-f08f-42c9-a8a4-e5699e075606",                        [{"x":[-0.3,-0.18888888888888888,-0.07777777777777778,0.033333333333333326,0.14444444444444443,0.2555555555555556,0.36666666666666664,0.4777777777777777,0.5888888888888888,0.7],"y":[0.2,0.25555555555555554,0.3111111111111111,0.3666666666666667,0.4222222222222222,0.4777777777777778,0.5333333333333333,0.5888888888888888,0.6444444444444444,0.7],"z":[[0.7701164963941324,0.6283092958909083,0.5415527126716361,0.5098467467363137,0.5331913980849422,0.6115866667175217,0.7450325526340511,0.9335290558345314,1.1770761763189612,1.4756739140873447],[0.7441715121348315,0.6136606079279046,0.5382003210049284,0.5177906513659022,0.5524315990108271,0.6421231639397025,0.7868653461525285,0.9866581456493052,1.2415015624300334,1.5513955964947104],[0.7213129476286172,0.6020983397179872,0.5379343490913059,0.5288209757485777,0.5747582196897988,0.6757460809149707,0.831784559424093,1.0428736552171658,1.3090133682941905,1.6302036986551645],[0.7015408028754901,0.5936224912611562,0.5407547969307722,0.5429377198843395,0.6001712601218568,0.712455417643325,0.8797901924487439,1.102175584538113,1.3796115939114335,1.712098220568703],[0.6848550778754495,0.5882330625574113,0.5466616645233243,0.5601408837731872,0.6286707203070012,0.7522511741247649,0.9308822452264809,1.164563933612146,1.453296239281762,1.7970791622353286],[0.6712557726284948,0.5859300536067533,0.5556549518689623,0.5804304674151216,0.6602566002452317,0.7951333503592921,0.985060717757304,1.230038702439266,1.5300673044051791,1.885146523655042],[0.6607428871346267,0.5867134644091807,0.5677346589676865,0.6038064708101425,0.6949288999365489,0.8411019463469066,1.042325610041214,1.298599891019471,1.6099247892816813,1.97630030482784],[0.6533164213938455,0.5905832949646959,0.5829007858194974,0.6302688939582497,0.7326876193809523,0.890156962087606,1.102676922078209,1.3702474993527647,1.6928686939112694,2.0705405057537236],[0.6489763754061499,0.5975395452732973,0.6011533324243955,0.6598177368594436,0.7735327585784424,0.9422983975813923,1.1661146538682923,1.4449815274391422,1.7788990182939437,2.1678671264326956],[0.6477227491715418,0.607582215334985,0.6224922987823789,0.6924529995137233,0.8174643175290193,0.997526252828266,1.232638805411461,1.5228019752786075,1.8680157624297056,2.2682801668647548]],"type":"surface"},{"line":{"color":"#101010","width":2},"name":"","x":[0.9517816258230679,0.9061130680575759,0.8628604828797082,0.8218970500532169,0.7831026043640945,0.7463632863958373,0.7115712116303959,0.6786241569131664,0.6474252633708371,0.6178827549187238,0.5899096715395276,0.5634236165583811,0.5383465171797234,0.5146043975900828,0.4921271639673703,0.470848400771882,0.4507051777270022,0.4316378669286589,0.413589969552024,0.3965079516518377,0.38034108857916804,0.3650413175624533,0.35056309802440516,0.3368632792288301,0.32390097487272873,0.3116374442592186,0.30003597970594736,0.28906179986178937,0.278681948621784,0.2688651993465484,0.25958196410780837,0.25080420769630213,0.2425053661421484,0.23466026951088625,0.22724506875081946,0.22023716637907156,0.21361515080491425,0.20735873409950156,0.20144869303115892,0.19586681319486565,0.19059583607356237,0.18561940887743447,0.18092203701539672,0.1764890390606531,0.17230650407945466,0.16836125119904552,0.16464079129729509,0.1611332907026802,0.15782753679912334,0.15471290543572894,0.15177933004670538,0.14901727239172974,0.14641769483172232,0.14397203405945952,0.1416721762086823,0.1395104332693628,0.13747952074058822,0.13557253645611764,0.13378294052107517 ...

# %% [markdown]
# ## Heathrow 2019

# %%
#This will translate your chosen weather data into the X and y datasets needed for the optimization function.

X=index.to_numpy().reshape(n_rows,1)
#Represent x_0 as a vector of 1s for vector computation
ones = np.ones((n_rows,1))
X = np.concatenate((ones, X), axis=1)
y=df2019['HEATHROW_temp_mean'].to_numpy().reshape(n_rows,1) #<----INSERT WEATHER STATION HERE

# %%
X.shape, y.shape
# Out:
# ((365, 2), (365, 1))

# %%
#Look at one year of temperature data over time
plt.scatter(x=index['index'], y=df2019['HEATHROW_temp_mean']) #<----INSERT WEATHER STATION HERE
plt.xlabel('X'); plt.ylabel('y');
plt.title('Input dataset');
plt.show()

# %%
#what is the min temperature? (Note gradient descent is not actually finding this number)
df2019['HEATHROW_temp_mean'].min()
# Out:
# -2.02830870294598

# %%
#what is the max temperature? (Note gradient descent is not actually finding this number)
df2019['HEATHROW_temp_mean'].max()
# Out:
# 3.073302321227288

# %%
#Run data through a gradiant descent for the starting conditions in 'theta_init'.

num_iterations=100
theta_init=np.array([[0.5],[1]]) 
alpha=0.01 
theta, J_history, theta0_history, theta1_history = gradient_descent(X,y, theta_init,
                                                                   alpha, num_iterations)

# %%
#Plot loss, theta0, and theta1.

fig, ax1 = plt.subplots()

# plot thetas over time
color='tab:blue'
ax1.plot(theta0_history, label='$\\theta_{0}$', linestyle='--', color=color)
ax1.plot(theta1_history, label='$\\theta_{1}$', linestyle='-', color=color)
# ax1.legend()
ax1.set_xlabel('Iterations'); ax1.set_ylabel('$\\theta$', color=color);
ax1.tick_params(axis='y', labelcolor=color)

# plot loss function over time
color='tab:red'
ax2 = ax1.twinx()
ax2.plot(J_history, label='Loss function', color=color)
ax2.set_title('Values of $\\theta$ and $J(\\theta)$ over iterations')
ax2.set_ylabel('Loss: $J(\\theta)$', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# ax2.legend();
fig.legend();

plt.show()

# %%
# theta range
theta0_vals = np.linspace(.2,.7,10) 
theta1_vals = np.linspace(-.3,.7,10) 

J_vals = np.zeros((len(theta0_vals), len(theta1_vals)))

# compute cost for each combination of theta
c1=0; c2=0
for i in theta0_vals:
    for j in theta1_vals:
        t = np.array([i, j])
        J_vals[c1][c2] = compute_cost(X, y, t.transpose()).tolist()[0]
        c2=c2+1
    c1=c1+1
    c2=0

# %%
#Loss Function Figure

#X = Theta0
#Y - Theta1
#Z = Loss
#black line = path of loss function over the iterations.
#Find where it is closest to 0 in X and Y!

line_marker = dict(color='#101010', width=2)
fig = go.Figure()
fig.add_surface(x=theta1_vals, y=theta0_vals, z=J_vals)
fig.add_scatter3d(x=theta1_history, y=theta0_history, z=J_history, line=line_marker, name='')
#The below line adds a graph of just the loss over iterations in a 2D plane
plt.plot(theta0_history, theta1_history, 'r+');
fig.update_layout(title='Loss function for different thetas', autosize=True,
                  width=600, height=600, xaxis_title='theta0', 
                 yaxis_title='theta1')
fig.show()
# Out:
# <div>                            <div id="f1368c20-d23b-4a7b-a5c5-eaf4047b82bc" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1368c20-d23b-4a7b-a5c5-eaf4047b82bc")) {                    Plotly.newPlot(                        "f1368c20-d23b-4a7b-a5c5-eaf4047b82bc",                        [{"x":[-0.3,-0.18888888888888888,-0.07777777777777778,0.033333333333333326,0.14444444444444443,0.2555555555555556,0.36666666666666664,0.4777777777777777,0.5888888888888888,0.7],"y":[0.2,0.25555555555555554,0.3111111111111111,0.3666666666666667,0.4222222222222222,0.4777777777777778,0.5333333333333333,0.5888888888888888,0.6444444444444444,0.7],"z":[[0.7206067113960439,0.5829382607800114,0.5003204274479296,0.4727532113997988,0.5002366126356178,0.5827706311553876,0.7203552669591089,0.9129905200467804,1.1606763904184016,1.4634128780739748],[0.6932044582926592,0.5668323039729224,0.49551076693713686,0.47923984718530244,0.5180195447174181,0.6118498595334839,0.7607307916335012,0.964662341017469,1.2236445076853872,1.5376772916372565],[0.6688886249423596,0.5538127669189199,0.4937875261794306,0.48881290272389183,0.538888896552304,0.6440155076646668,0.8041927360609801,1.0194205817412438,1.289699044705458,1.615028124953623],[0.6476592113451473,0.543879649618004,0.49515070517481063,0.5014723780155685,0.562844668140277,0.6792675755489362,0.8507411002415457,1.0772652422181053,1.358840001478617,1.6954653780230775],[0.629516217501021,0.5370329520701739,0.4996003039232771,0.517218273060331,0.5898868594813356,0.7176060631862912,0.9003758841751971,1.1381963224480531,1.43106737800486,1.7789890508456172],[0.6144596434099813,0.5332726742754306,0.50713632242483,0.5360505878581808,0.6200154705754813,0.7590309705767333,0.9530970878619347,1.2022138224310877,1.5063811742841904,1.8655991434212453],[0.6024894890720282,0.5325988162337736,0.5177587606794691,0.5579693224091155,0.6532305014227128,0.8035422977202615,1.0089047113017593,1.2693177421672086,1.5847813903166077,1.9552956557499577],[0.5936057544871616,0.5350113779452028,0.5314676186871954,0.582974476713138,0.6895319520230312,0.8511400446168756,1.0677987544946703,1.3395080816564158,1.6662680261021103,2.0480785878317587],[0.5878084396553804,0.5405103594097187,0.5482628964480073,0.6110660507702463,0.7289198223764362,0.901824211266577,1.129779217440668,1.4127848408987091,1.7508410816407018,2.1439479396666448],[0.585097544576687,0.5490957606273206,0.5681445939619059,0.6422440445804417,0.7713941124829274,0.9555947976693647,1.194846100139751,1.4891480198940885,1.8385005569323762,2.2429037112546175]],"type":"surface"},{"line":{"color":"#101010","width":2},"name":"","x":[0.9514091383332207,0.9053799024239689,0.8617778451179776,0.8204755744738869,0.781352383538439,0.7442938995493464,0.7091917515463583,0.6759432554245496,0.6444511155145463,0.6146231418224289,0.5863719821075699,0.559614868019776,0.5342733745579715,0.5102731921513692,0.48754391070075864,0.466018814952302,0.4456346906091597,0.42633164061747425,0.4080529110928097,0.39074472638116114,0.374356132775193,0.3588388504315217,0.3441471330586894,0.3302376349680588,0.317069285101258,0.3046031676680778,0.2928024090479368,0.2816320706262297,0.27105904725412583,0.2610519710367239,0.2515811201699563,0.24261833256130827,0.23413692398331898,0.22611161052200607,0.2185184350948354,0.21133469782468556,0.20453889006746256,0.19811063190163797,0.19203061289804493,0.18628053599779965,0.18084306433524802,0.1757017708513966,0.17084109055139593,0.166246275267329,0.16190335079483786,0.15779907627902065,0.1539209057315675,0.15025695156729818,0.14679595005413248,0.14352722857608535,0.14044067461414758,0.13752670635490577,0.1347762448414849,0.13218068758587997,0.1297318835659898,0.12742210953469,0.1252440475720957,0.12319076381577718,0.12125568830711471,0.119 ...

# %% [markdown]
# ## Budapest 1970

# %%
#This will translate your chosen weather data into the X and y datasets needed for the optimization function.

X=index.to_numpy().reshape(n_rows,1)
#Represent x_0 as a vector of 1s for vector computation
ones = np.ones((n_rows,1))
X = np.concatenate((ones, X), axis=1)
y=df1970['BUDAPEST_temp_mean'].to_numpy().reshape(n_rows,1) #<----INSERT WEATHER STATION HERE

# %%
X.shape, y.shape
# Out:
# ((365, 2), (365, 1))

# %%
#Look at one year of temperature data over time
plt.scatter(x=index['index'], y=df1970['BUDAPEST_temp_mean']) #<----INSERT WEATHER STATION HERE
plt.xlabel('X'); plt.ylabel('y');
plt.title('Input dataset');
plt.show()

# %%
#what is the min temperature? (Note gradient descent is not actually finding this number)
df1970['BUDAPEST_temp_mean'].min()
# Out:
# -2.204923068571174

# %%
#what is the min temperature? (Note gradient descent is not actually finding this number)
df1970['BUDAPEST_temp_mean'].max()
# Out:
# 1.6417097760175523

# %%
#Run data through a gradiant descent for the starting conditions in 'theta_init'.

num_iterations=100 
theta_init=np.array([[0.5],[1]]) 
alpha=0.01 
theta, J_history, theta0_history, theta1_history = gradient_descent(X,y, theta_init,
                                                                   alpha, num_iterations)

# %%
#Plot loss, theta0, and theta1.

fig, ax1 = plt.subplots()

# plot thetas over time
color='tab:blue'
ax1.plot(theta0_history, label='$\\theta_{0}$', linestyle='--', color=color)
ax1.plot(theta1_history, label='$\\theta_{1}$', linestyle='-', color=color)
# ax1.legend()
ax1.set_xlabel('Iterations'); ax1.set_ylabel('$\\theta$', color=color);
ax1.tick_params(axis='y', labelcolor=color)

# plot loss function over time
color='tab:red'
ax2 = ax1.twinx()
ax2.plot(J_history, label='Loss function', color=color)
ax2.set_title('Values of $\\theta$ and $J(\\theta)$ over iterations')
ax2.set_ylabel('Loss: $J(\\theta)$', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# ax2.legend();
fig.legend();

plt.show()

# %%
# theta range
theta0_vals = np.linspace(.2,.7,10) 
theta1_vals = np.linspace(-.3,.7,10) 

J_vals = np.zeros((len(theta0_vals), len(theta1_vals)))

# compute cost for each combination of theta
c1=0; c2=0
for i in theta0_vals:
    for j in theta1_vals:
        t = np.array([i, j])
        J_vals[c1][c2] = compute_cost(X, y, t.transpose()).tolist()[0]
        c2=c2+1
    c1=c1+1
    c2=0

# %%
#Loss Function Figure

#X = Theta0
#Y - Theta1
#Z = Loss
#black line = path of loss function over the iterations.
#Find where it is closest to 0 in X and Y!

line_marker = dict(color='#101010', width=2)
fig = go.Figure()
fig.add_surface(x=theta1_vals, y=theta0_vals, z=J_vals)
fig.add_scatter3d(x=theta1_history, y=theta0_history, z=J_history, line=line_marker, name='')
#The below line adds a graph of just the loss over iterations in a 2D plane
plt.plot(theta0_history, theta1_history, 'r+');
fig.update_layout(title='Loss function for different thetas', autosize=True,
                  width=600, height=600, xaxis_title='theta0', 
                 yaxis_title='theta1')
fig.show()
# Out:
# <div>                            <div id="67cf6a4f-3125-4041-91cd-ca2394fb0f17" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67cf6a4f-3125-4041-91cd-ca2394fb0f17")) {                    Plotly.newPlot(                        "67cf6a4f-3125-4041-91cd-ca2394fb0f17",                        [{"x":[-0.3,-0.18888888888888888,-0.07777777777777778,0.033333333333333326,0.14444444444444443,0.2555555555555556,0.36666666666666664,0.4777777777777777,0.5888888888888888,0.7],"y":[0.2,0.25555555555555554,0.3111111111111111,0.3666666666666667,0.4222222222222222,0.4777777777777778,0.5333333333333333,0.5888888888888888,0.6444444444444444,0.7],"z":[[0.6508528240610393,0.5645500800855796,0.53329795339407,0.5570964439865105,0.6359455518629024,0.7698452770232446,0.9587956194675367,1.2027965791957806,1.5018481562079746,1.8559503505041193],[0.6392976360534997,0.5642911883743351,0.5443353579791228,0.5794301448678594,0.6695755490405483,0.8147715704971854,1.0150182092377746,1.2703154652623143,1.5806633385708042,1.946061829163244],[0.6308288677990466,0.5671187164161785,0.5584591823172621,0.6048502655022953,0.7062919659712793,0.8627842837242147,1.0743272187610995,1.3409207710819355,1.6625649406867222,2.039259727575459],[0.6254465192976794,0.5730326642111084,0.5756694264084875,0.6333568058898165,0.746094802655098,0.9138834167043284,1.1367226480375099,1.414612496654643,1.7475529625557251,2.135544045740758],[0.6231505905493991,0.5820330317591237,0.5959660902527996,0.6649497660304254,0.7889840590920028,0.9680689694375301,1.2022044970670074,1.4913906419804366,1.8356274041778144,2.234914783659144],[0.6239410815542051,0.5941198190602267,0.6193491738501988,0.6996291459241208,0.8349597352819932,1.0253409419238175,1.2707727658495915,1.5712552070593147,1.9267882655529915,2.3373719413306175],[0.6278179923120971,0.6092930261144148,0.6458186772006832,0.737394945570902,0.8840218312250714,1.0856993341631909,1.3424274543852612,1.6542061918912818,2.0210355466812544,2.442915518755177],[0.6347813228230756,0.6275526529216894,0.6753746003042539,0.7782471649707696,0.9361703469212354,1.1491441461556515,1.4171685626740178,1.7402435964763352,2.1183692475626015,2.551545515932821],[0.6448310730871412,0.6488986994820517,0.7080169431609118,0.8221858041237233,0.9914052823704856,1.215675377901198,1.49499609071586,1.8293674208144741,2.2187893681970383,2.663261932863553],[0.6579672431042923,0.6733311657954988,0.7437457057706564,0.8692108630297639,1.0497266375728211,1.2852930293998308,1.5759100385107911,1.9215776649057004,2.3222959085845614,2.778064769547373]],"type":"surface"},{"line":{"color":"#101010","width":2},"name":"","x":[0.9467862247355692,0.8963924158013244,0.8486705362086644,0.8034803173835705,0.7606888515161531,0.7201702053017933,0.6818050539513519,0.6454803344068154,0.6110889167545706,0.578529292881379,0.5477052814682363,0.5185257484647783,0.490904342231889,0.46475924258279033,0.44001292299328654,0.41659192529010736,0.39442664616255724,0.373451134877039,0.3536029016065771,0.3348227358183144,0.3170545341911879,0.3002451375636829,0.28434417643780957,0.26930392459031205,0.2550791603656786,0.24162703524784968,0.22890694932866984,0.21688043331117626,0.20551103670480475,0.19476422188759096,0.18460726372749425,0.17500915447112694,0.16594051362348047,0.157373502556744,0.1492817436000548,0.1416402433750419,0.13442532015436373,0.1276145350321316,0.12118662670618925,0.11512144968271468,0.1093999157235572,0.10400393836614584,0.09891638035473481,0.09412100383021284,0.08960242313371958,0.08534606008690887,0.08133810161889583,0.07756545961674477,0.07401573288281693,0.07067717108841981,0.0675386406190015,0.06458959221163049,0.06182003029071027,0.059220483912813204,0.05678197923619456,0.05449601343497872,0.05235452998220778,0.050349895229921025,0.048474876 ...

# %% [markdown]
# ## Budapest 1997

# %%
#This will translate your chosen weather data into the X and y datasets needed for the optimization function.

X=index.to_numpy().reshape(n_rows,1)
#Represent x_0 as a vector of 1s for vector computation
ones = np.ones((n_rows,1))
X = np.concatenate((ones, X), axis=1)
y=df1997['BUDAPEST_temp_mean'].to_numpy().reshape(n_rows,1) #<----INSERT WEATHER STATION HERE

# %%
X.shape, y.shape
# Out:
# ((365, 2), (365, 1))

# %%
#Look at one year of temperature data over time
plt.scatter(x=index['index'], y=df1997['BUDAPEST_temp_mean']) #<----INSERT WEATHER STATION HERE
plt.xlabel('X'); plt.ylabel('y');
plt.title('Input dataset');
plt.show()

# %%
#what is the min temperature? (Note gradient descent is not actually finding this number)
df1997['BUDAPEST_temp_mean'].min()
# Out:
# -2.287266890932401

# %%
#what is the max temperature? (Note gradient descent is not actually finding this number)
df1997['BUDAPEST_temp_mean'].max()
# Out:
# 1.9122680494901545

# %%
#Run data through a gradiant descent for the starting conditions in 'theta_init'.

num_iterations=100 
theta_init=np.array([[0.5],[1]]) 
alpha=0.01 
theta, J_history, theta0_history, theta1_history = gradient_descent(X,y, theta_init,
                                                                   alpha, num_iterations)

# %%
#Plot loss, theta0, and theta1.

fig, ax1 = plt.subplots()

# plot thetas over time
color='tab:blue'
ax1.plot(theta0_history, label='$\\theta_{0}$', linestyle='--', color=color)
ax1.plot(theta1_history, label='$\\theta_{1}$', linestyle='-', color=color)
# ax1.legend()
ax1.set_xlabel('Iterations'); ax1.set_ylabel('$\\theta$', color=color);
ax1.tick_params(axis='y', labelcolor=color)

# plot loss function over time
color='tab:red'
ax2 = ax1.twinx()
ax2.plot(J_history, label='Loss function', color=color)
ax2.set_title('Values of $\\theta$ and $J(\\theta)$ over iterations')
ax2.set_ylabel('Loss: $J(\\theta)$', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# ax2.legend();
fig.legend();

plt.show()

# %%
# theta range
theta0_vals = np.linspace(.2,.7,10) 
theta1_vals = np.linspace(-.3,.7,10) 

J_vals = np.zeros((len(theta0_vals), len(theta1_vals)))

# compute cost for each combination of theta
c1=0; c2=0
for i in theta0_vals:
    for j in theta1_vals:
        t = np.array([i, j])
        J_vals[c1][c2] = compute_cost(X, y, t.transpose()).tolist()[0]
        c2=c2+1
    c1=c1+1
    c2=0

# %%
#Loss Function Figure

#X = Theta0
#Y - Theta1
#Z = Loss
#black line = path of loss function over the iterations.
#Find where it is closest to 0 in X and Y!

line_marker = dict(color='#101010', width=2)
fig = go.Figure()
fig.add_surface(x=theta1_vals, y=theta0_vals, z=J_vals)
fig.add_scatter3d(x=theta1_history, y=theta0_history, z=J_history, line=line_marker, name='')
#The below line adds a graph of just the loss over iterations in a 2D plane
plt.plot(theta0_history, theta1_history, 'r+');
fig.update_layout(title='Loss function for different thetas', autosize=True,
                  width=600, height=600, xaxis_title='theta0', 
                 yaxis_title='theta1')
fig.show()
# Out:
# <div>                            <div id="37e6f02e-85c4-4d63-be5f-6d15e59fcc0e" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37e6f02e-85c4-4d63-be5f-6d15e59fcc0e")) {                    Plotly.newPlot(                        "37e6f02e-85c4-4d63-be5f-6d15e59fcc0e",                        [{"x":[-0.3,-0.18888888888888888,-0.07777777777777778,0.033333333333333326,0.14444444444444443,0.2555555555555556,0.36666666666666664,0.4777777777777777,0.5888888888888888,0.7],"y":[0.2,0.25555555555555554,0.3111111111111111,0.3666666666666667,0.4222222222222222,0.4777777777777778,0.5333333333333333,0.5888888888888888,0.6444444444444444,0.7],"z":[[0.6501497653149889,0.5545986588146562,0.5140981695982737,0.528648297665842,0.5982490430173607,0.7229004056528308,0.9026023855722506,1.1373549827756213,1.4271581972629424,1.772012029034215],[0.6345391574847011,0.5502843472806647,0.5210801543605792,0.5469265787244432,0.6278236203722588,0.7637712793040248,0.9547695555197402,1.200818449019408,1.501917959803026,1.8580680878705924],[0.6220149694075003,0.5490564554997597,0.5311485588759701,0.5682912795361306,0.6604846174802427,0.8077285727083048,1.0100231452203183,1.2673683350162803,1.5797641420961936,1.947210566460059],[0.6125772010833858,0.5509149834719409,0.5443033831444474,0.5927424001009045,0.6962320343413133,0.854772285865671,1.0683631546739794,1.3370046407662397,1.6606967441424503,2.0394394648026113],[0.6062258525123568,0.5558599311972091,0.5605446271660123,0.6202799404187658,0.735065870955469,0.9049024187761238,1.1297895838807295,1.409727366269285,1.744715765941791,2.134754782898248],[0.6029609236944147,0.5638912986755633,0.5798722909406626,0.6509039004897125,0.7769861273227128,0.9581189714396636,1.1943024328405651,1.4855365115254158,1.8318212074942202,2.233156520746974],[0.6027824146295591,0.575009085907004,0.6022863744683989,0.6846142803137448,0.8219928034430425,1.014421943856289,1.2619017015534872,1.5644320765346362,1.9220130687997354,2.3346446783487855],[0.6056903253177904,0.5892132928915312,0.6277868777492221,0.7214110798908652,0.8700858993164582,1.0738113360260018,1.332587390019496,1.6464140612969407,2.015291349858335,2.4392192557036836],[0.6116846557591067,0.6065039196291436,0.6563738007831332,0.7612942992210708,0.9212654149429605,1.1362871479488008,1.4063594982385912,1.7314824658123316,2.111656050670024,2.546880252811666],[0.620765405953511,0.6268809661198441,0.6880471435701296,0.8042639383043638,0.9755313503225492,1.2018493796246854,1.4832180262107728,1.8196372900808098,2.2111071712347976,2.657627669672737]],"type":"surface"},{"line":{"color":"#101010","width":2},"name":"","x":[0.9476185773628077,0.8980066470669043,0.8510188351414273,0.8065173962569185,0.7643718134095784,0.7244584186122267,0.6866600334896342,0.6508656287337367,0.6169700014290521,0.5848734693105573,0.5544815810654864,0.5257048418371411,0.4984584531329822,0.4726620663811331,0.44823954941908917,0.42511876523601233,0.4032313623255991,0.38251257604025346,0.36290104036926757,0.34433860959400625,0.3267701893017972,0.3101435762674248,0.29440930673689725,0.2795205126725753,0.26543278554188665,0.2521040472537743,0.23949442786779915,0.22756614972049946,0.2162834176322589,0.20561231487560727,0.19552070460262028,0.1859781364449502,0.17695575801505228,0.16842623105141458,0.16036365196409577,0.15274347654966322,0.14554244865674068,0.1387385325948559,0.13231084909015742,0.126239614601877,0.12050608382318208,0.11509249519931558,0.1099820193046903,0.10515870992891325,0.10060745772958783,0.09631394631720125,0.09226461064447289,0.08844659757923609,0.08484772854627166,0.08145646412952433,0.07826187053183022,0.07525358779468194,0.07242179968567265,0.0697572051661071,0.06725099135585982,0.064894807916912,0.06268074278112122,0.06060129915168524,0.0586493737114 ...

# %% [markdown]
# ## Budapest 2019

# %%
#This will translate your chosen weather data into the X and y datasets needed for the optimization function.

X=index.to_numpy().reshape(n_rows,1)
#Represent x_0 as a vector of 1s for vector computation
ones = np.ones((n_rows,1))
X = np.concatenate((ones, X), axis=1)
y=df2019['BUDAPEST_temp_mean'].to_numpy().reshape(n_rows,1) #<----INSERT WEATHER STATION HERE

# %%
X.shape, y.shape
# Out:
# ((365, 2), (365, 1))

# %%
#Look at one year of temperature data over time
plt.scatter(x=index['index'], y=df2019['BUDAPEST_temp_mean']) #<----INSERT WEATHER STATION HERE
plt.xlabel('X'); plt.ylabel('y');
plt.title('Input dataset');
plt.show()

# %%
#what is the min temperature? (Note gradient descent is not actually finding this number)
df2019['BUDAPEST_temp_mean'].min()
# Out:
# -1.699096731209354

# %%
#what is the max temperature? (Note gradient descent is not actually finding this number)
df2019['BUDAPEST_temp_mean'].max()
# Out:
# 2.100482500601529

# %%
#Run data through a gradiant descent for the starting conditions in 'theta_init'.

num_iterations=100 
theta_init=np.array([[0.5],[1]]) 
alpha=0.01 
theta, J_history, theta0_history, theta1_history = gradient_descent(X,y, theta_init,
                                                                   alpha, num_iterations)

# %%
#Plot loss, theta0, and theta1.

fig, ax1 = plt.subplots()

# plot thetas over time
color='tab:blue'
ax1.plot(theta0_history, label='$\\theta_{0}$', linestyle='--', color=color)
ax1.plot(theta1_history, label='$\\theta_{1}$', linestyle='-', color=color)
# ax1.legend()
ax1.set_xlabel('Iterations'); ax1.set_ylabel('$\\theta$', color=color);
ax1.tick_params(axis='y', labelcolor=color)

# plot loss function over time
color='tab:red'
ax2 = ax1.twinx()
ax2.plot(J_history, label='Loss function', color=color)
ax2.set_title('Values of $\\theta$ and $J(\\theta)$ over iterations')
ax2.set_ylabel('Loss: $J(\\theta)$', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# ax2.legend();
fig.legend();

plt.show()

# %%
# theta range
theta0_vals = np.linspace(.2,.7,10) 
theta1_vals = np.linspace(-.3,.7,10) 

J_vals = np.zeros((len(theta0_vals), len(theta1_vals)))

# compute cost for each combination of theta
c1=0; c2=0
for i in theta0_vals:
    for j in theta1_vals:
        t = np.array([i, j])
        J_vals[c1][c2] = compute_cost(X, y, t.transpose()).tolist()[0]
        c2=c2+1
    c1=c1+1
    c2=0

# %%
#Loss Function Figure

#X = Theta0
#Y - Theta1
#Z = Loss
#black line = path of loss function over the iterations.
#Find where it is closest to 0 in X and Y!

line_marker = dict(color='#101010', width=2)
fig = go.Figure()
fig.add_surface(x=theta1_vals, y=theta0_vals, z=J_vals)
fig.add_scatter3d(x=theta1_history, y=theta0_history, z=J_history, line=line_marker, name='')
#The below line adds a graph of just the loss over iterations in a 2D plane
plt.plot(theta0_history, theta1_history, 'r+');
fig.update_layout(title='Loss function for different thetas', autosize=True,
                  width=600, height=600, xaxis_title='theta0', 
                 yaxis_title='theta1')
fig.show()
# Out:
# <div>                            <div id="6eb7296d-0b70-41b5-8b6e-0be130c2d987" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6eb7296d-0b70-41b5-8b6e-0be130c2d987")) {                    Plotly.newPlot(                        "6eb7296d-0b70-41b5-8b6e-0be130c2d987",                        [{"x":[-0.3,-0.18888888888888888,-0.07777777777777778,0.033333333333333326,0.14444444444444443,0.2555555555555556,0.36666666666666664,0.4777777777777777,0.5888888888888888,0.7],"y":[0.2,0.25555555555555554,0.3111111111111111,0.3666666666666667,0.4222222222222222,0.4777777777777778,0.5333333333333333,0.5888888888888888,0.6444444444444444,0.7],"z":[[0.771950513778646,0.6116562143761525,0.5064125322576092,0.456219467423017,0.4610770198723754,0.5209851896056844,0.6359439766229436,0.8059533809241537,1.0310134025093138,1.3111240413784253],[0.7391370478216649,0.5901390447154667,0.4961916588932207,0.457294890354924,0.4734487391005783,0.5446532051301839,0.6709082884437391,0.8522139890412457,1.088570306922702,1.3799772420881098],[0.7094100016177696,0.5717082948078684,0.48905720528191765,0.46145673303991774,0.48890687808186817,0.5714076404077699,0.7089590200176216,0.9015610169114247,1.149213631089177,1.4519168625508814],[0.6827693751669601,0.5563639646533556,0.4850091714237012,0.46870499547799704,0.5074514368162443,0.6012484954384422,0.7500961713445904,0.9539944645346891,1.2129433750087386,1.5269429027667392],[0.6592151684692367,0.5441060542519288,0.484047557318571,0.47903967766916367,0.5290824153037073,0.634175770222201,0.7943197424246454,1.0095143319110402,1.2797595386813867,1.6050553627356832],[0.6387473815246014,0.5349345636035887,0.48617236296652744,0.49246077961341694,0.553799813544256,0.6701894647590462,0.8416297332577869,1.0681206190404784,1.3496621221071208,1.686254242457713],[0.6213660143330509,0.5288494927083353,0.4913835883675707,0.508968301310756,0.5816036315378919,0.7092895790489779,0.8920261438440152,1.1298133259230025,1.4226511252859404,1.77053954193283],[0.6070710668945881,0.525850841566168,0.49968123352169924,0.528562242761181,0.6124938692846139,0.7514761130919957,0.9455089741833295,1.1945924525586127,1.4987265482178476,1.857911261161034],[0.5958625392092122,0.5259386101770875,0.5110652984289156,0.5512426039646929,0.6464705267844212,0.7967490668881005,1.00207822427573,1.2624579989473101,1.577888390902841,1.9483694001423235],[0.5877404312769208,0.5291127985410933,0.5255357830892174,0.5770093849212911,0.683533604037316,0.8451084404372912,1.0617338941212178,1.3334099650890936,1.6601366533409212,2.0419139588767]],"type":"surface"},{"line":{"color":"#101010","width":2},"name":"","x":[0.9534454647240023,0.9093439288403009,0.8675666491435774,0.8279916383168423,0.790503310413806,0.7549921449446827,0.7213543685892065,0.6894916536118648,0.6593108321028948,0.6307236252145814,0.6036463866059721,0.5779998593504186,0.5537089455994765,0.5307024883337712,0.508913064566562,0.4882767893990182,0.46873313035776193,0.45022473147511216,0.4326972466007772,0.41609918146057306,0.4003817440031646,0.3854987025999122,0.3714062516857299,0.35806288445048545,0.3454292722109625,0.33346815011282,0.32214420883038075,0.31142399194951004,0.301275798735363,0.29166959200242754,0.28257691081911857,0.2739707877932279,0.2658256706978489,0.2581173482100073,0.250822879546183,0.24392052779023163,0.23738969671994659,0.2312108709486686,0.22536555920798498,0.2198362406066887,0.2146063137098169,0.20966004828978446,0.20498253960939333,0.2005596651038567,0.19637804333594877,0.19242499510499728,0.18868850659669487,0.18515719446663703,0.1818202727561132,0.1786675215440033,0.1756892572436767,0.1728763044585718,0.17021996931466377,0.1677120141923202,0.16534463378411157,0.16311043240899623,0.16100240251695147,0.1590139043215817,0.1571386465015123,0.1553 ...

# %% [markdown]
# ## Oslo 1970

# %%
#This will translate your chosen weather data into the X and y datasets needed for the optimization function.

X=index.to_numpy().reshape(n_rows,1)
#Represent x_0 as a vector of 1s for vector computation
ones = np.ones((n_rows,1))
X = np.concatenate((ones, X), axis=1)
y=df1970['OSLO_temp_mean'].to_numpy().reshape(n_rows,1) #<----INSERT WEATHER STATION HERE

# %%
X.shape, y.shape
# Out:
# ((365, 2), (365, 1))

# %%
#Look at one year of temperature data over time
plt.scatter(x=index['index'], y=df1970['OSLO_temp_mean']) #<----INSERT WEATHER STATION HERE
plt.xlabel('X'); plt.ylabel('y');
plt.title('Input dataset');
plt.show()

# %%
#what is the min temperature? (Note gradient descent is not actually finding this number)
df1970['OSLO_temp_mean'].min()
# Out:
# -2.977590859818025

# %%
#what is the max temperature? (Note gradient descent is not actually finding this number)
df1970['OSLO_temp_mean'].max()
# Out:
# 2.167586554500124

# %%
#Run data through a gradiant descent for the starting conditions in 'theta_init'.

num_iterations=100 
theta_init=np.array([[0.5],[1]]) 
alpha=0.01 
theta, J_history, theta0_history, theta1_history = gradient_descent(X,y, theta_init,
                                                                   alpha, num_iterations)

# %%
#Plot loss, theta0, and theta1.

fig, ax1 = plt.subplots()

# plot thetas over time
color='tab:blue'
ax1.plot(theta0_history, label='$\\theta_{0}$', linestyle='--', color=color)
ax1.plot(theta1_history, label='$\\theta_{1}$', linestyle='-', color=color)
# ax1.legend()
ax1.set_xlabel('Iterations'); ax1.set_ylabel('$\\theta$', color=color);
ax1.tick_params(axis='y', labelcolor=color)

# plot loss function over time
color='tab:red'
ax2 = ax1.twinx()
ax2.plot(J_history, label='Loss function', color=color)
ax2.set_title('Values of $\\theta$ and $J(\\theta)$ over iterations')
ax2.set_ylabel('Loss: $J(\\theta)$', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# ax2.legend();
fig.legend();

plt.show()

# %%
# theta range
theta0_vals = np.linspace(.2,.7,10) 
theta1_vals = np.linspace(-.3,.7,10) 

J_vals = np.zeros((len(theta0_vals), len(theta1_vals)))

# compute cost for each combination of theta
c1=0; c2=0
for i in theta0_vals:
    for j in theta1_vals:
        t = np.array([i, j])
        J_vals[c1][c2] = compute_cost(X, y, t.transpose()).tolist()[0]
        c2=c2+1
    c1=c1+1
    c2=0

# %%
#Loss Function Figure

#X = Theta0
#Y - Theta1
#Z = Loss
#black line = path of loss function over the iterations.
#Find where it is closest to 0 in X and Y!

line_marker = dict(color='#101010', width=2)
fig = go.Figure()
fig.add_surface(x=theta1_vals, y=theta0_vals, z=J_vals)
fig.add_scatter3d(x=theta1_history, y=theta0_history, z=J_history, line=line_marker, name='')
#The below line adds a graph of just the loss over iterations in a 2D plane
plt.plot(theta0_history, theta1_history, 'r+');
fig.update_layout(title='Loss function for different thetas', autosize=True,
                  width=600, height=600, xaxis_title='theta0', 
                 yaxis_title='theta1')
fig.show()
# Out:
# <div>                            <div id="05bc68f9-29bb-4984-b7e4-05c45c1804ad" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05bc68f9-29bb-4984-b7e4-05c45c1804ad")) {                    Plotly.newPlot(                        "05bc68f9-29bb-4984-b7e4-05c45c1804ad",                        [{"x":[-0.3,-0.18888888888888888,-0.07777777777777778,0.033333333333333326,0.14444444444444443,0.2555555555555556,0.36666666666666664,0.4777777777777777,0.5888888888888888,0.7],"y":[0.2,0.25555555555555554,0.3111111111111111,0.3666666666666667,0.4222222222222222,0.4777777777777778,0.5333333333333333,0.5888888888888888,0.6444444444444444,0.7],"z":[[0.8575232553857715,0.7694138118351699,0.7363549855685211,0.7583467765858233,0.835389184887074,0.9674822104722768,1.1546258533414298,1.3968201134945342,1.6940649909315875,2.046360485652593],[0.8495312219427876,0.7727180746884841,0.7509555447181323,0.7842436320317294,0.8725823366292773,1.0159716585107759,1.214411597676225,1.4679021541256256,1.7764433278589749,2.1400351188762765],[0.8446256082528928,0.779108757294885,0.7686425236208274,0.8132269072307223,0.912861908124565,1.067547526302362,1.2772837617641075,1.5420706145098022,1.8619080845394496,2.2367961718530487],[0.8428064143160809,0.7885858596543704,0.7894159222766102,0.8452966021828002,0.956227899372942,1.122209813847033,1.343242345605075,1.619325494647066,1.9504592609730087,2.336643644582905],[0.8440736401323575,0.8011493817669441,0.8132757406854791,0.8804527168879662,1.0026803103744033,1.1799585211447914,1.4122873491991266,1.6996667945374178,2.0420968571596565,2.439577537065847],[0.8484272857017211,0.8167993236326028,0.8402219788474347,0.9186952513462178,1.0522191411289512,1.240793648195635,1.4844187725462694,1.7830945141808539,2.1368208730993907,2.5455978493018776],[0.8558673510241697,0.8355356852513482,0.8702546367624758,0.9600242055575551,1.104844391636585,1.3047151949995655,1.559636615646496,1.8696086535773777,2.234631308792209,2.65470458129099],[0.8663938360997068,0.8573584666231803,0.9033737144306053,1.0044395795219798,1.160556061897307,1.3717231615565815,1.6379408784998102,1.959209212726986,2.3355281642381147,2.766897733033194],[0.8800067409283265,0.8822676677480985,0.9395792118518204,1.0519413732394918,1.2193541519111135,1.4418175478666875,1.719331561106209,2.0518961916296834,2.4395114394371085,2.882177304528482],[0.8967060655100372,0.9102632886261043,0.9788711290261216,1.102529586710089,1.2812386616780072,1.514998353929877,1.8038086634656958,2.1476695902854654,2.5465811343891875,3.000543295776859]],"type":"surface"},{"line":{"color":"#101010","width":2},"name":"","x":[0.9469488276973318,0.8967221081273173,0.8491715413319774,0.8041566096255963,0.7615441692169584,0.7212080632613467,0.6830287552177701,0.6468929814458959,0.6126934220330766,0.5803283888948412,0.5497015302424199,0.5207215505584366,0.4933019452669729,0.46736074932691135,0.4428202990179289,0.41960700622685265,0.3976511445784159,0.3768866467888764,0.3572509126535734,0.33868462711040304,0.32113158785047585,0.3045385419749644,0.2888550312234386,0.27403324532389806,0.2600278830383117,0.24679602049984076,0.23429698645911137,0.22249224407698234,0.21134527892027824,0.20082149283498515,0.19088810338848736,0.1815140485886076,0.17266989660254867,0.16432776021336518,0.1564612157653616,0.14904522636285888,0.14205606909913274,0.13547126610403865,0.12926951920993715,0.12343064804604748,0.11793553138132182,0.11276605154537292,0.10790504176593316,0.10333623626979901,0.09904422300224629,0.09501439882751066,0.09123292708013911,0.08768669734384929,0.08436328734100762,0.08125092682197077,0.07833846334934687,0.07561532987774,0.07307151403475938,0.07069752901401868,0.0684843859955359,0.06642356801338277,0.06450700519463894,0.0627270512976911,0.061076461481693635, ...

# %% [markdown]
# ## Oslo 1997

# %%
#This will translate your chosen weather data into the X and y datasets needed for the optimization function.

X=index.to_numpy().reshape(n_rows,1)
#Represent x_0 as a vector of 1s for vector computation
ones = np.ones((n_rows,1))
X = np.concatenate((ones, X), axis=1)
y=df1997['OSLO_temp_mean'].to_numpy().reshape(n_rows,1) #<----INSERT WEATHER STATION HERE

# %%
X.shape, y.shape
# Out:
# ((365, 2), (365, 1))

# %%
#Look at one year of temperature data over time
plt.scatter(x=index['index'], y=df1997['OSLO_temp_mean']) #<----INSERT WEATHER STATION HERE
plt.xlabel('X'); plt.ylabel('y');
plt.title('Input dataset');
plt.show()

# %%
#what is the min temperature? (Note gradient descent is not actually finding this number)
df1997['OSLO_temp_mean'].min()
# Out:
# -2.528601321304413

# %%
#what is the max temperature? (Note gradient descent is not actually finding this number)
df1997['OSLO_temp_mean'].max()
# Out:
# 2.009833473400747

# %%
#Run data through a gradiant descent for the starting conditions in 'theta_init'.

num_iterations=100 
theta_init=np.array([[0.5],[1]]) 
alpha=0.01 
theta, J_history, theta0_history, theta1_history = gradient_descent(X,y, theta_init,
                                                                   alpha, num_iterations)

# %%
#Plot loss, theta0, and theta1.

fig, ax1 = plt.subplots()

# plot thetas over time
color='tab:blue'
ax1.plot(theta0_history, label='$\\theta_{0}$', linestyle='--', color=color)
ax1.plot(theta1_history, label='$\\theta_{1}$', linestyle='-', color=color)
# ax1.legend()
ax1.set_xlabel('Iterations'); ax1.set_ylabel('$\\theta$', color=color);
ax1.tick_params(axis='y', labelcolor=color)

# plot loss function over time
color='tab:red'
ax2 = ax1.twinx()
ax2.plot(J_history, label='Loss function', color=color)
ax2.set_title('Values of $\\theta$ and $J(\\theta)$ over iterations')
ax2.set_ylabel('Loss: $J(\\theta)$', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# ax2.legend();
fig.legend();

plt.show()

# %%
# theta range
theta0_vals = np.linspace(.2,.7,10) 
theta1_vals = np.linspace(-.3,.7,10) 

J_vals = np.zeros((len(theta0_vals), len(theta1_vals)))

# compute cost for each combination of theta
c1=0; c2=0
for i in theta0_vals:
    for j in theta1_vals:
        t = np.array([i, j])
        J_vals[c1][c2] = compute_cost(X, y, t.transpose()).tolist()[0]
        c2=c2+1
    c1=c1+1
    c2=0

# %%
#Loss Function Figure

#X = Theta0
#Y - Theta1
#Z = Loss
#black line = path of loss function over the iterations.
#Find where it is closest to 0 in X and Y!

line_marker = dict(color='#101010', width=2)
fig = go.Figure()
fig.add_surface(x=theta1_vals, y=theta0_vals, z=J_vals)
fig.add_scatter3d(x=theta1_history, y=theta0_history, z=J_history, line=line_marker, name='')
#The below line adds a graph of just the loss over iterations in a 2D plane
plt.plot(theta0_history, theta1_history, 'r+');
fig.update_layout(title='Loss function for different thetas', autosize=True,
                  width=600, height=600, xaxis_title='theta0', 
                 yaxis_title='theta1')
fig.show()
# Out:
# <div>                            <div id="906d85c8-a191-41d4-9eb4-87fbf5abe481" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("906d85c8-a191-41d4-9eb4-87fbf5abe481")) {                    Plotly.newPlot(                        "906d85c8-a191-41d4-9eb4-87fbf5abe481",                        [{"x":[-0.3,-0.18888888888888888,-0.07777777777777778,0.033333333333333326,0.14444444444444443,0.2555555555555556,0.36666666666666664,0.4777777777777777,0.5888888888888888,0.7],"y":[0.2,0.25555555555555554,0.3111111111111111,0.3666666666666667,0.4222222222222222,0.4777777777777778,0.5333333333333333,0.5888888888888888,0.6444444444444444,0.7],"z":[[0.7605765207882849,0.6374148634740804,0.5693038234438275,0.5562434006975251,0.5982335952351728,0.6952744070567718,0.8473658361623214,1.0545078825518215,1.3167005462252719,1.633943827182674],[0.7372967897424498,0.6254314287245423,0.568616684990585,0.5668525585405791,0.620139049374524,0.7284761574924192,0.8918638828942651,1.1103022255800614,1.3837911855498084,1.7123307628035054],[0.7171034784497018,0.6165344137280906,0.5710159662904303,0.5805481361367207,0.6451309232669618,0.764764327681153,0.9394483493792944,1.169182988361387,1.4539682446274311,1.7938041181774247],[0.699996586910041,0.6107238184847255,0.5765016673433614,0.5973301334859482,0.6732092169124854,0.8041389176229725,0.9901192356174107,1.2311501708958001,1.5272317234581392,1.8783638933044309],[0.685976115123465,0.6079996429944472,0.5850737881493795,0.6171985505882616,0.7043739303110954,0.8465999273178795,1.0438765416086142,1.296203773183298,1.6035816220419354,1.966010088184521],[0.6750420630899762,0.608361887257254,0.5967323287084833,0.6401533874436621,0.7386250634627918,0.8921473567658722,1.1007202673529042,1.364343795223884,1.6830179403788166,2.056742702817699],[0.6671944308095747,0.6118105512731479,0.6114772890206737,0.6661946440521485,0.7759626163675757,0.9407812059669519,1.1606504128502788,1.4355702370175565,1.7655406784687846,2.150561737203964],[0.6624332182822583,0.6183456350421287,0.62930866908595,0.6953223204137213,0.816386589025444,0.9925014749211167,1.2236669781007408,1.509883098564315,1.85114983631184,2.247467191343315],[0.6607584255080294,0.6279671385641961,0.6502264689043132,0.7275364165283816,0.8598969814363995,1.04730816362837,1.2897699631042887,1.5872823798641595,1.9398454139079804,2.3474590652357517],[0.6621700524868862,0.6406750618393499,0.674230688475763,0.762836932396127,0.9064937936004428,1.1052012720887086,1.3589593678609235,1.6677680809170905,2.031627411257208,2.450537358881275]],"type":"surface"},{"line":{"color":"#101010","width":2},"name":"","x":[0.9501035269360562,0.9028404777351082,0.8580726306614911,0.815669017279594,0.7755055418343341,0.7374646206047702,0.7014348401827574,0.6673106336835453,0.6349919739473369,0.6043840828401985,0.5753971558095046,0.5479461008934285,0.5219502914260004,0.4973333317190496,0.4740228350400691,0.4519502132407656,0.43105047742492403,0.41126204907629327,0.3925265810976012,0.3747887882406077,0.3579962864343991,0.34209944054498503,0.32705122012376225,0.3128070627256274,0.2993247443995183,0.2865642569750082,0.27448769178832855,0.26305912950990784,0.2522445357532483,0.2420116621617626,0.23232995268611262,0.2231704547796769,0.21450573525406644,0.2063098005501512,0.19855802119289173,0.1912270602104296,0.18429480530941045,0.17774030460943052,0.17154370574984001,0.16568619819193792,0.16014995854887917,0.15491809878441362,0.14997461712991417,0.14530435157705068,0.14089293581095205,0.1367267574557907,0.13279291851144445,0.12907919786625854,0.12557401577696306,0.12226640021251946,0.11914595496408509,0.11620282942841866,0.11342768997691192,0.11081169282704151,0.10834645833740067,0.10602404665160842,0.10383693462031288,0.10177799393422078,0.09984047040460384,0.0 ...

# %% [markdown]
# ## Oslo 2019

# %%
#This will translate your chosen weather data into the X and y datasets needed for the optimization function.

X=index.to_numpy().reshape(n_rows,1)
#Represent x_0 as a vector of 1s for vector computation
ones = np.ones((n_rows,1))
X = np.concatenate((ones, X), axis=1)
y=df2019['OSLO_temp_mean'].to_numpy().reshape(n_rows,1) #<----INSERT WEATHER STATION HERE

# %%
X.shape, y.shape
# Out:
# ((365, 2), (365, 1))

# %%
#Look at one year of temperature data over time
plt.scatter(x=index['index'], y=df2019['OSLO_temp_mean']) #<----INSERT WEATHER STATION HERE
plt.xlabel('X'); plt.ylabel('y');
plt.title('Input dataset');
plt.show()

# %%
#what is the min temperature? (Note gradient descent is not actually finding this number)
df2019['OSLO_temp_mean'].min()
# Out:
# -2.067476930398541

# %%
#what is the max temperature? (Note gradient descent is not actually finding this number)
df2019['OSLO_temp_mean'].max()
# Out:
# 2.288935078422722

# %%
#Run data through a gradiant descent for the starting conditions in 'theta_init'.

num_iterations=100 
theta_init=np.array([[0.5],[1]]) 
alpha=0.01 
theta, J_history, theta0_history, theta1_history = gradient_descent(X,y, theta_init,
                                                                   alpha, num_iterations)

# %%
#Plot loss, theta0, and theta1.

fig, ax1 = plt.subplots()

# plot thetas over time
color='tab:blue'
ax1.plot(theta0_history, label='$\\theta_{0}$', linestyle='--', color=color)
ax1.plot(theta1_history, label='$\\theta_{1}$', linestyle='-', color=color)
# ax1.legend()
ax1.set_xlabel('Iterations'); ax1.set_ylabel('$\\theta$', color=color);
ax1.tick_params(axis='y', labelcolor=color)

# plot loss function over time
color='tab:red'
ax2 = ax1.twinx()
ax2.plot(J_history, label='Loss function', color=color)
ax2.set_title('Values of $\\theta$ and $J(\\theta)$ over iterations')
ax2.set_ylabel('Loss: $J(\\theta)$', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# ax2.legend();
fig.legend();

plt.show()

# %%
# theta range
theta0_vals = np.linspace(.2,.7,10) 
theta1_vals = np.linspace(-.3,.7,10) 

J_vals = np.zeros((len(theta0_vals), len(theta1_vals)))

# compute cost for each combination of theta
c1=0; c2=0
for i in theta0_vals:
    for j in theta1_vals:
        t = np.array([i, j])
        J_vals[c1][c2] = compute_cost(X, y, t.transpose()).tolist()[0]
        c2=c2+1
    c1=c1+1
    c2=0

# %%
#Loss Function Figure

#X = Theta0
#Y - Theta1
#Z = Loss
#black line = path of loss function over the iterations.
#Find where it is closest to 0 in X and Y!

line_marker = dict(color='#101010', width=2)
fig = go.Figure()
fig.add_surface(x=theta1_vals, y=theta0_vals, z=J_vals)
fig.add_scatter3d(x=theta1_history, y=theta0_history, z=J_history, line=line_marker, name='')
#The below line adds a graph of just the loss over iterations in a 2D plane
plt.plot(theta0_history, theta1_history, 'r+');
fig.update_layout(title='Loss function for different thetas', autosize=True,
                  width=600, height=600, xaxis_title='theta0', 
                 yaxis_title='theta1')
fig.show()
# Out:
# <div>                            <div id="5332c314-b007-4024-a506-20aa79e793f5" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5332c314-b007-4024-a506-20aa79e793f5")) {                    Plotly.newPlot(                        "5332c314-b007-4024-a506-20aa79e793f5",                        [{"x":[-0.3,-0.18888888888888888,-0.07777777777777778,0.033333333333333326,0.14444444444444443,0.2555555555555556,0.36666666666666664,0.4777777777777777,0.5888888888888888,0.7],"y":[0.2,0.25555555555555554,0.3111111111111111,0.3666666666666667,0.4222222222222222,0.4777777777777778,0.5333333333333333,0.5888888888888888,0.6444444444444444,0.7],"z":[[0.6165965215851325,0.49759348003276493,0.4336410557643492,0.4247392487798842,0.47088805907936876,0.5720874866628046,0.7283375315301909,0.9396381936815276,1.2059894731168155,1.5273913698360537],[0.5928938253645905,0.48518708010852,0.43253095213640025,0.43492544144823114,0.4923705480440121,0.6048662719237449,0.7724126130874274,0.9950095715350599,1.2726571472666437,1.6053553402821803],[0.5722775488971347,0.4758670999373611,0.43450726826153735,0.4481980538696644,0.5169394567617426,0.640731476937771,0.8195741143977496,1.0534673691416796,1.3424112411695597,1.686405730481389],[0.5547476921827661,0.4696335395192888,0.43957000413976105,0.46455708604418466,0.5445947852325591,0.6796831017048839,0.869822035461159,1.1150115865013848,1.4152517548255605,1.770542540433688],[0.5403042552214841,0.46648639885430254,0.44771915977107196,0.48400253797179127,0.5753365334564616,0.7217211462250825,0.9231563762776546,1.1796422236141761,1.4911786882346485,1.857765770139072],[0.528947238013288,0.46642567794240297,0.45895473515546825,0.5065344096524834,0.6091647014334505,0.766845610498368,0.9795771368472358,1.247359280480054,1.570192041396823,1.9480754195975438],[0.5206766405581787,0.46945137678358906,0.4732767302929513,0.5321527010862634,0.6460792891635265,0.8150564945247398,1.0390843171699045,1.318162757099019,1.6522918143120837,2.0414714888090995],[0.5154924628561558,0.47556349537786285,0.4906851451835213,0.5608574122731292,0.6860802966466888,0.8663537983041987,1.1016779172456588,1.3920526534710689,1.7374780069804314,2.1379539777737424],[0.5133947049072182,0.4847620337252221,0.5111799798271767,0.5926485432130815,0.7291677238829365,0.9207375218367432,1.1673579370744998,1.4690289695962058,1.8257506194018642,2.237522886491473],[0.5143833667113688,0.4970469918256677,0.5347612342239182,0.6275260939061206,0.7753415708722731,0.9782076651223739,1.2361243766564274,1.5490917054744302,1.9171096515763846,2.3401782149622896]],"type":"surface"},{"line":{"color":"#101010","width":2},"name":"","x":[0.9497292515174908,0.9021072229658813,0.8569948991339205,0.8142605597288676,0.7737793965730652,0.7354331508882512,0.6991097696135005,0.6647030797579991,0.6321124798422681,0.6012426475311132,0.5720032626086355,0.544308744490223,0.518078003508689,0.4932342052517558,0.4697045472660084,0.447420047478385,0.42631534372032137,0.40632850377193425,0.38740084537420083,0.3694767656860604,0.352503579690813,0.33643136708219673,0.32121282718517125,0.30680314148978194,0.2931598433986066,0.2802426948092496,0.2680135691732112,0.2564363406912831,0.2454767793234535,0.2351024513082026,0.2252826249020829,0.21598818106564655,0.20719152883615957,0.1988665251411617,0.1909883988198372,0.18353367863139006,0.17648012504120456,0.16980666558655033,0.16349333363399418,0.1575212103505377,0.15187236971983947,0.1465298264437297,0.14147748657761083,0.13670010075628258,0.13218321987425774,0.12791315309176865,0.1238769280444231,0.12006225314087206,0.11645748183892038,0.11305157879626096,0.1098340877974607,0.1067951013639891,0.10392523195897099,0.10121558470297991,0.09865773152157965,0.0962436866494826,0.09396588342013579,0.09181715227328154,0.08 ...
